# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.16.0-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.16.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6

# %%
from datasets import load_dataset

# %%
import pandas as pd
import numpy as np
import torch

# %%
raw_bh_tr = open('/content/drive/MyDrive/bmmnerdataset/Bhojpuri_ner.remove[1].train').readlines()

# %%
def preprocess(raw):
  all_x = []

  point = []

  for line in raw:
      stripped_line = line.strip().split('\t')
      point.append(stripped_line)
      if line == '\n':
          all_x.append(point[:-1])
          point = []

  all_x = all_x[:-1]
  X = [[c[0] for c in x] for x in all_x]
  Y = [[c[1] for c in y] for y in all_x]
  return X,Y

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
bh_X_tr,bh_Y_tr=preprocess(raw_bh_tr)

# %%
len(bh_X_tr)
# Out:
# 11543

# %%
raw_mt_tr = open('/content/drive/MyDrive/bmmnerdataset/Maithili_ner[1].train').readlines()
mt_X_tr,mt_Y_tr=preprocess(raw_mt_tr)

# %%
len(mt_X_tr)
# Out:
# 7848

# %%
all_labels = [c for y in mt_Y_tr for c in y]

n_labels = len(set(all_labels))

# %%
print(bh_X_tr[2])
print(bh_Y_tr[2])
# Out:
# ['माई', 'बाप', 'बिहीन', 'टूअर', 'लइकी', 'के', 'बिकल', 'आर्त', 'भाव', 'पर', 'कुन्ती', 'के', 'मन', 'भरि', 'आइल', '।']
# ['OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'B-Person', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER']

# %%
labels=list(set(all_labels))
labels.sort()

# %%
labels
# Out:
# ['B-Artifact',
#  'B-Count',
#  'B-Date',
#  'B-Day',
#  'B-Disease',
#  'B-Distance',
#  'B-Entertainment',
#  'B-Facility',
#  'B-Location',
#  'B-Locomotive',
#  'B-Material',
#  'B-Money',
#  'B-Month',
#  'B-Organism',
#  'B-Organization',
#  'B-Period',
#  'B-Person',
#  'B-Plant',
#  'B-Quantity',
#  'B-Special_Day',
#  'B-Time',
#  'B-Year',
#  'I-Artifact',
#  'I-Count',
#  'I-Date',
#  'I-Day',
#  'I-Disease',
#  'I-Distance',
#  'I-Entertainment',
#  'I-Facility',
#  'I-Location',
#  'I-Locomotive',
#  'I-Material',
#  'I-Money',
#  'I-Month',
#  'I-Organism',
#  'I-Organization',
#  'I-Period',
#  'I-Person',
#  'I-Plant',
#  'I-Quantity',
#  'I-Special_Day',
#  'I-Time',
#  'I-Year',
#  'OTHER']

# %%
label2ind = {label: (index) for index, label in enumerate(labels)}

# %%
def cat(y):
  return [[label2ind[w] for w in s] for s in y]

# %%
bh_Y_tr = cat(bh_Y_tr)

# %%
bh_Y_tr[2]
# Out:
# [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 16, 44, 44, 44, 44, 44]

# %%
df_bh=pd.DataFrame(list(zip(bh_X_tr,bh_Y_tr)),columns=['tokens','ner_tags'])

# %%
df_bh.head(20)
# Out:
#                                                tokens  \
# 0   [दोसर, ई, कि, ई, पूरा, कहानी, कल्पना, ह, ,, कव...
# 1     [जाने, केतना, मकानन, के, रूख, मरा, गइल, रहे, ।]
# 2   [माई, बाप, बिहीन, टूअर, लइकी, के, बिकल, आर्त, ...
# 3         [सिकुमार, ओही, गलती, में, पकड़ाइल, रहलें, ।]
# 4   [जब, ले, भोजपुरी, कहानी, अपना, समय, के, नबुज, ...
# 5   [एकरा, बाद, सुकन्या, के, अपना, बाप, ,, राजा, स...
# 6   [आ, जब, रुसी, सैनिक, आवऽतारे, स, आ, ऊ, धधा, के...
# 7                                                 [।]
# 8   [समाज, जवाबदेही, तय, कऽ, के, अइसन, काम, करा, स...
# 9   [4, ,, 9, ,, 14, तारीख, अउरी, मंगलवार, के, एह,...
# 10                 [समय, पर, पइसा, ना, जूटी, परले, ।]
# 11               [मनढींठ, लइकन, क, का, उपाय, करसु, ।]
# 12  [ओकर, रूप, देखि, घायल, मनहीं, मन, भुनभुनाये, ल...
# 13                  [’, -, ‘का, ,, राजा, क, धियरी, ?]
# 14  [जइसन, कि, हर, पुरान, शहर, का, ,, हर, पुरान, म...
# 15  [राउर, बेटी, नीलम, हमरा, आ, हमरा, बेटा, के, पं...
# 16  [जब, जब, चुनाव, आवेला, त, ओसे, कुछ, दिन, पहिले...
# 17  [सुराज, के, बासठ, बरिस, बाद, भोजपुरी, के, भावन...
# 18  [आज, तऽ, हालत, ई, बा, कि, गोड़, कब्र, में, लटकल...
# 19  [एकरा, डर, से, बड़, बड़, पंडित, लोग, के, पतरा,...
#
#                                              ner_tags
# 0   [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 1                [44, 44, 44, 44, 44, 44, 44, 44, 44]
# 2   [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 16, 4...
# 3                        [16, 44, 44, 44, 44, 44, 44]
# 4   [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 5   [44, 44, 16, 44, 44, 44, 44, 44, 16, 44, 44, 4...
# 6   [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 7                                                [44]
# 8   [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 9   [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 10                       [44, 44, 44, 44, 44, 44, 44]
# 11                       [44, 44, 44, 44, 44, 44, 44]
# 12               [44, 44, 44, 16, 44, 44, 44, 44, 44]
# 13                   [44, 44, 44, 44, 44, 44, 44, 44]
# 14  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 15       [44, 44, 16, 44, 44, 44, 44, 44, 44, 44, 44]
# 16  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 17  [44, 44, 15, 15, 44, 44, 44, 44, 44, 44, 44, 4...
# 18  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 19       [44, 44, 44, 44, 44, 16, 44, 44, 44, 44, 44]

# %%
from datasets import Dataset

# %%
dataset_bh_tr=Dataset.from_pandas(df_bh)

# %%
dataset_bh_tr
# Out:
# Dataset({
#     features: ['tokens', 'ner_tags'],
#     num_rows: 11543
# })

# %%
dataset_bh_ev
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'ner_tags'],
#         num_rows: 10388
#     })
#     test: Dataset({
#         features: ['tokens', 'ner_tags'],
#         num_rows: 1155
#     })
# })

# %%
raw_bh_te = open('/content/drive/MyDrive/bmmnerdataset/Bhojpuri_ner.remove[1].test').readlines()

# %%
bh_X_te,bh_Y_te=preprocess(raw_bh_te)

# %%
len(bh_X_te)
# Out:
# 4947

# %%
bh_Y_te = cat(bh_Y_te)

# %%
df_bh_te=pd.DataFrame(list(zip(bh_X_te,bh_Y_te)),columns=['tokens','ner_tags'])

# %%
dataset_bh_te=Dataset.from_pandas(df_bh_te)

# %%
# Load model directly
from transformers import AutoModelForTokenClassification, AutoConfig, AutoTokenizer, TrainingArguments, Trainer, DataCollatorForTokenClassification, EarlyStoppingCallback, IntervalStrategy

#tokenizer = AutoTokenizer.from_pretrained("ai4bharat/IndicNER")

#config = AutoConfig.from_pretrained("ai4bharat/IndicNER")
#model=AutoModelForTokenClassification.from_pretrained(config)
tokenizer = AutoTokenizer.from_pretrained("ai4bharat/IndicBERTv2-MLM-only",keep_accents=True)
#model = AutoModelForTokenClassification.from_pretrained("ai4bharat/IndicBERTv2-MLM-only",num_labels=n_labels)

# %%
model=model.to("cuda")

# %%
text_column_name = "tokens"
label_column_name = "ner_tags"

# %%
# Tokenize all texts and align the labels with them.
padding = "max_length"
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples[text_column_name],
        padding=padding,
        truncation='longest_first',
        max_length=512,
        # We use this argument because the texts in our dataset are lists of words (with a label for each word).
        is_split_into_words=True,
    )
    labels = []
    for i, label in enumerate(examples[label_column_name]):
        # print('=====')
        # print('{} {}'.format(i,label)) #ak
        word_ids = tokenized_inputs.word_ids(batch_index=i)

        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            # Special tokens have a word id that is None. We set the label to -100 so they are automatically
            # ignored in the loss function.
            if word_idx is None:
                label_ids.append(-100)
            # We set the label for the first token of each word.
            elif word_idx != previous_word_idx:
                label_ids.append(label[word_idx])
            # For the other tokens in a word, we set the label to either the current label or -100, depending on
            # the label_all_tokens flag.
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx

        labels.append(label_ids)
    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
dataset_bh_tr
# Out:
# Dataset({
#     features: ['tokens', 'ner_tags'],
#     num_rows: 11543
# })

# %%
train_dataset = dataset_bh_tr
train_dataset = train_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on train dataset",
)
# Out:
# Running tokenizer on train dataset (num_proc=4):   0%|          | 0/11543 [00:00<?, ? examples/s]

# %%
eval_dataset = dataset_bh_ev["test"]
eval_dataset = eval_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on eval dataset",
)

# %%
dataset_bh_te
# Out:
# Dataset({
#     features: ['tokens', 'ner_tags'],
#     num_rows: 4947
# })

# %%
test_dataset = dataset_bh_te
test_dataset = test_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on test dataset",
)
# Out:
# Running tokenizer on test dataset (num_proc=4):   0%|          | 0/4947 [00:00<?, ? examples/s]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer)

# %%
from datasets import load_metric

# %%
# !pip3 install sentencepiece
# !pip3 install seqeval
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.5 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.2.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=6d5d1260ef7e296555addb43d8a992a081eb2fc55e95ee93bb0dbf95c02b7fe2
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
label_list = labels

# %%
# Metrics
metric = load_metric("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    # Remove ignored index (special tokens)
    true_predictions = [
        [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [label_list[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    # Unpack nested dictionaries
    final_results = {}
    for key, value in results.items():
        if isinstance(value, dict):
            for n, v in value.items():
                final_results[f"{key}_{n}"] = v
        else:
            final_results[key] = value
    return final_results
# Out:
# <ipython-input-18-435f98c90f62>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("seqeval")
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:752: FutureWarning: The repository for seqeval contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.16.0/metrics/seqeval/seqeval.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.47k [00:00<?, ?B/s]

# %%
pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.1)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.1.0+cu121)
# Collecting accelerate>=0.20.3 (from transformers[torch])
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.10->transformers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.10->transformers[torch]) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.25.0

# %%
pip install accelerate -U
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
# args=TrainingArguments(output_dir='output_dir',max_steps=5)
args=TrainingArguments(
    output_dir='output_dir',
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=4)

# %%
# Initialize our Trainer
#early_stopping_callback = EarlyStoppingCallback(early_stopping_patience=2)
#args.metric_for_best_model = "f1"
#args.load_best_model_at_end = True
#args.evaluation_strategy = IntervalStrategy.STEPS
#args.eval_steps = args.save_steps
#args.greater_is_better = True

trainer = Trainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    #callbacks=[early_stopping_callback],
    args=args,
)

# %%
train_result = trainer.train()
# Out:
# You're using a AlbertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='5772' max='5772' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5772/5772 1:07:02, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.342300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.233500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.207900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.175100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.170500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.149300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.136000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.129300</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.124300</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.099400</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.104100</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='619' max='619' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [619/619 02:47]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        4.0
#   eval_Artifact_f1             =     0.2088
#   eval_Artifact_number         =        170
#   eval_Artifact_precision      =     0.3291
#   eval_Artifact_recall         =     0.1529
#   eval_Count_f1                =     0.2458
#   eval_Count_number            =        159
#   eval_Count_precision         =     0.2606
#   eval_Count_recall            =     0.2327
#   eval_Date_f1                 =        0.0
#   eval_Date_number             =         17
#   eval_Date_precision          =        0.0
#   eval_Date_recall             =        0.0
#   eval_Day_f1                  =        0.0
#   eval_Day_number              =          9
#   eval_Day_precision           =        0.0
#   eval_Day_recall              =        0.0
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          9
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          3
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =        0.1
#   eval_Entertainment_number    =         74
#   eval_Entertainment_precision =     0.6667
#   eval_Entertainment_recall    =     0.0541
#   eval_Facility_f1             =        0.0
#   eval_Facility_number         =         32
#   eval_Facility_precision      =        0.0
#   eval_Facility_recall         =        0.0
#   eval_Location_f1             =     0.4176
#   eval_Location_number         =        259
#   eval_Location_precision      =     0.4847
#   eval_Location_recall         =     0.3668
#   eval_Locomotive_f1           =     0.3333
#   eval_Locomotive_number       =         35
#   eval_Locomotive_precision    =     0.6154
#   eval_Locomotive_recall       =     0.2286
#   eval_Material_f1             =        0.0
#   eval_Material_number         =         89
#   eval_Material_precision      =        0.0
#   eval_Material_recall         =        0.0
#   eval_Money_f1                =        0.0
#   eval_Money_number            =         35
#   eval_Money_precision         =        0.0
#   eval_Money_recall            =        0.0
#   eval_Month_f1                =        0.0
#   eval_Month_number            =         20
#   eval_Month_precision         =        0.0
#   eval_Month_recall            =        0.0
#   eval_Organism_f1             =     0.0833
#   eval_Organism_number         =        136
#   eval_Organism_precision      =       0.75
#   eval_Organism_recall         =     0.0441
#   eval_Organization_f1         =        0.0
#   eval_Organization_number     =         16
#   eval_Organization_precision  =        0.0
#   eval_Organization_recall     =        0.0
#   eval_Period_f1               =        0.0
#   eval_Period_number           =         59
#   eval_Period_precision        =        0.0
#   eval_Period_recall           =        0.0
#   eval_Person_f1               =     0.7458
#   eval_Person_number           =       1534
#   eval_Person_precision        =     0.7778
#   eval_Person_recall           =     0.7164
#   eval_Plant_f1                =        0.0
#   eval_Plant_number            =         44
#   eval_Plant_precision         =        0.0
#   eval_Plant_recall            =        0.0
#   eval_Quantity_f1             =     0.0328
#   eval_Quantity_number         =         55
#   eval_Quantity_precision      =     0.1667
#   eval_Quantity_recall         =     0.0182
#   eval_Special_Day_f1          =        0.0
#   eval_Special_Day_number      =          1
#   eval_Special_Day_precision   =        0.0
#   eval_Special_Day_recall      =        0.0
#   eval_Time_f1                 =        0.0
#   eval_Time_number             =         42
#   eval_Time_precision          =        0.0
#   eval_Time_recall             =        0.0
#   eval_Year_f1                 =        0.0
#   eval_Year_number             =         11
#   eval_Year_precision          =        0.0
#   eval_Year_recall             =        0.0
#   eval_loss                    =     0.1598
#   eval_overall_accuracy        =     0.9669
#   eval_overall_f1              =     0.5454
#   eval_overall_precision       =     0.6824
#   eval_overall_recall          =     0.4543
#   eval_runtime                 = 0:02:51.08
#   eval_samples_per_second      =     28.916
#   eval_steps_per_second        =      3.618

# %%
train_result = trainer.train()
# Out:
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3441' max='5772' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3441/5772 45:29 < 30:50, 1.26 it/s, Epoch 2.38/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.265500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.167000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.147700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.116400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.112600</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.101700</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='5772' max='5772' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5772/5772 1:16:49, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.265500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.167000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.147700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.116400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.112600</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.101700</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.084100</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.081200</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.075500</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.060600</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.061300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
train_result = trainer.train()
# Out:
#     <div>
#
#       <progress value='4329' max='4329' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4329/4329 1:01:22, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.160400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.126600</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.108900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.073200</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.073100</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.070300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.051600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.051800</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
metrics = train_result.metrics

# %%
metrics
# Out:
# {'train_runtime': 3355.8474,
#  'train_samples_per_second': 10.319,
#  'train_steps_per_second': 1.29,
#  'total_flos': 9051963065994240.0,
#  'train_loss': 0.14089192879285348,
#  'epoch': 3.0}

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='619' max='619' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [619/619 02:23]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        4.0
#   eval_Artifact_f1             =     0.4438
#   eval_Artifact_number         =        170
#   eval_Artifact_precision      =     0.4154
#   eval_Artifact_recall         =     0.4765
#   eval_Count_f1                =      0.297
#   eval_Count_number            =        159
#   eval_Count_precision         =     0.3125
#   eval_Count_recall            =      0.283
#   eval_Date_f1                 =     0.3429
#   eval_Date_number             =         17
#   eval_Date_precision          =     0.3333
#   eval_Date_recall             =     0.3529
#   eval_Day_f1                  =     0.2353
#   eval_Day_number              =          9
#   eval_Day_precision           =       0.25
#   eval_Day_recall              =     0.2222
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          9
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          3
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =     0.3652
#   eval_Entertainment_number    =         74
#   eval_Entertainment_precision =     0.5122
#   eval_Entertainment_recall    =     0.2838
#   eval_Facility_f1             =     0.0455
#   eval_Facility_number         =         32
#   eval_Facility_precision      =     0.0833
#   eval_Facility_recall         =     0.0312
#   eval_Location_f1             =     0.7202
#   eval_Location_number         =        259
#   eval_Location_precision      =     0.7709
#   eval_Location_recall         =     0.6757
#   eval_Locomotive_f1           =     0.4952
#   eval_Locomotive_number       =         35
#   eval_Locomotive_precision    =     0.3714
#   eval_Locomotive_recall       =     0.7429
#   eval_Material_f1             =     0.3926
#   eval_Material_number         =         89
#   eval_Material_precision      =     0.4324
#   eval_Material_recall         =     0.3596
#   eval_Money_f1                =     0.2647
#   eval_Money_number            =         35
#   eval_Money_precision         =     0.2727
#   eval_Money_recall            =     0.2571
#   eval_Month_f1                =     0.4242
#   eval_Month_number            =         20
#   eval_Month_precision         =     0.5385
#   eval_Month_recall            =       0.35
#   eval_Organism_f1             =     0.2716
#   eval_Organism_number         =        136
#   eval_Organism_precision      =     0.3084
#   eval_Organism_recall         =     0.2426
#   eval_Organization_f1         =     0.2759
#   eval_Organization_number     =         16
#   eval_Organization_precision  =     0.3077
#   eval_Organization_recall     =       0.25
#   eval_Period_f1               =     0.1835
#   eval_Period_number           =         59
#   eval_Period_precision        =        0.2
#   eval_Period_recall           =     0.1695
#   eval_Person_f1               =     0.8294
#   eval_Person_number           =       1534
#   eval_Person_precision        =     0.8416
#   eval_Person_recall           =     0.8175
#   eval_Plant_f1                =     0.5319
#   eval_Plant_number            =         44
#   eval_Plant_precision         =        0.5
#   eval_Plant_recall            =     0.5682
#   eval_Quantity_f1             =     0.2202
#   eval_Quantity_number         =         55
#   eval_Quantity_precision      =     0.2222
#   eval_Quantity_recall         =     0.2182
#   eval_Special_Day_f1          =        0.0
#   eval_Special_Day_number      =          1
#   eval_Special_Day_precision   =        0.0
#   eval_Special_Day_recall      =        0.0
#   eval_Time_f1                 =     0.2333
#   eval_Time_number             =         42
#   eval_Time_precision          =     0.3889
#   eval_Time_recall             =     0.1667
#   eval_Year_f1                 =      0.381
#   eval_Year_number             =         11
#   eval_Year_precision          =        0.4
#   eval_Year_recall             =     0.3636
#   eval_loss                    =     0.1091
#   eval_overall_accuracy        =     0.9713
#   eval_overall_f1              =     0.6452
#   eval_overall_precision       =     0.6674
#   eval_overall_recall          =     0.6244
#   eval_runtime                 = 0:02:27.40
#   eval_samples_per_second      =     33.561
#   eval_steps_per_second        =      4.199

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='619' max='619' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [619/619 02:45]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        3.0
#   eval_Artifact_f1             =     0.5485
#   eval_Artifact_number         =        170
#   eval_Artifact_precision      =     0.5183
#   eval_Artifact_recall         =     0.5824
#   eval_Count_f1                =      0.367
#   eval_Count_number            =        159
#   eval_Count_precision         =     0.3571
#   eval_Count_recall            =     0.3774
#   eval_Date_f1                 =     0.3902
#   eval_Date_number             =         17
#   eval_Date_precision          =     0.3333
#   eval_Date_recall             =     0.4706
#   eval_Day_f1                  =        0.5
#   eval_Day_number              =          9
#   eval_Day_precision           =     0.4545
#   eval_Day_recall              =     0.5556
#   eval_Disease_f1              =     0.4286
#   eval_Disease_number          =          9
#   eval_Disease_precision       =        0.6
#   eval_Disease_recall          =     0.3333
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          3
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =     0.3509
#   eval_Entertainment_number    =         74
#   eval_Entertainment_precision =        0.5
#   eval_Entertainment_recall    =     0.2703
#   eval_Facility_f1             =     0.0833
#   eval_Facility_number         =         32
#   eval_Facility_precision      =      0.125
#   eval_Facility_recall         =     0.0625
#   eval_Location_f1             =     0.7237
#   eval_Location_number         =        259
#   eval_Location_precision      =     0.7459
#   eval_Location_recall         =     0.7027
#   eval_Locomotive_f1           =     0.5974
#   eval_Locomotive_number       =         35
#   eval_Locomotive_precision    =     0.5476
#   eval_Locomotive_recall       =     0.6571
#   eval_Material_f1             =     0.4972
#   eval_Material_number         =         89
#   eval_Material_precision      =     0.4891
#   eval_Material_recall         =     0.5056
#   eval_Money_f1                =     0.2667
#   eval_Money_number            =         35
#   eval_Money_precision         =       0.25
#   eval_Money_recall            =     0.2857
#   eval_Month_f1                =      0.619
#   eval_Month_number            =         20
#   eval_Month_precision         =     0.5909
#   eval_Month_recall            =       0.65
#   eval_Organism_f1             =      0.313
#   eval_Organism_number         =        136
#   eval_Organism_precision      =      0.383
#   eval_Organism_recall         =     0.2647
#   eval_Organization_f1         =     0.4138
#   eval_Organization_number     =         16
#   eval_Organization_precision  =     0.4615
#   eval_Organization_recall     =      0.375
#   eval_Period_f1               =     0.1803
#   eval_Period_number           =         59
#   eval_Period_precision        =     0.1746
#   eval_Period_recall           =     0.1864
#   eval_Person_f1               =     0.8536
#   eval_Person_number           =       1534
#   eval_Person_precision        =     0.8638
#   eval_Person_recall           =     0.8435
#   eval_Plant_f1                =     0.5979
#   eval_Plant_number            =         44
#   eval_Plant_precision         =     0.5472
#   eval_Plant_recall            =     0.6591
#   eval_Quantity_f1             =     0.2667
#   eval_Quantity_number         =         55
#   eval_Quantity_precision      =       0.28
#   eval_Quantity_recall         =     0.2545
#   eval_Special_Day_f1          =        0.0
#   eval_Special_Day_number      =          1
#   eval_Special_Day_precision   =        0.0
#   eval_Special_Day_recall      =        0.0
#   eval_Time_f1                 =        0.2
#   eval_Time_number             =         42
#   eval_Time_precision          =     0.3333
#   eval_Time_recall             =     0.1429
#   eval_Year_f1                 =     0.3571
#   eval_Year_number             =         11
#   eval_Year_precision          =     0.2941
#   eval_Year_recall             =     0.4545
#   eval_loss                    =     0.0897
#   eval_overall_accuracy        =     0.9733
#   eval_overall_f1              =     0.6791
#   eval_overall_precision       =     0.6927
#   eval_overall_recall          =     0.6661
#   eval_runtime                 = 0:02:49.13
#   eval_samples_per_second      =      29.25
#   eval_steps_per_second        =       3.66

# %%
tokenizer.save_pretrained('/content/drive/MyDrive/bh_indicbertv2')
model.save_pretrained('/content/drive/MyDrive/bh_indicbertv2')

# %%
def get_predictions( sentence, tokenizer, model ):
  # Let us first tokenize the sentence - split words into subwords
  tok_sentence = tokenizer(sentence, return_tensors='pt')

  with torch.no_grad():
    # we will send the tokenized sentence to the model to get predictions
    logits = model(**tok_sentence).logits.argmax(-1)

    # We will map the maximum predicted class id with the class label
    predicted_tokens_classes = [list(set(all_labels))[t] for t in logits[0]]

    predicted_labels = []

    previous_token_id = 0
    # we need to assign the named entity label to the head word and not the following sub-words
    word_ids = tok_sentence.word_ids()
    for word_index in range(len(word_ids)):
        if word_ids[word_index] == None:
            previous_token_id = word_ids[word_index]
        elif word_ids[word_index] == previous_token_id:
            previous_token_id = word_ids[word_index]
        else:
            predicted_labels.append( predicted_tokens_classes[ word_index ] )
            previous_token_id = word_ids[word_index]

    return predicted_labels

# %%
model.to('cpu')

# %%
sentence = 'अर्थशास्त्र के रचयिता चाणक्य के बारे में कुछ कहला से चुपे रहल ज्यादा श्रद्धास्पद होई ।'

predicted_labels = get_predictions(sentence=sentence,
                                   tokenizer=tokenizer,
                                   model=model
                                   )

for index in range(len(sentence.split(' '))):
  print( sentence.split(' ')[index] + '\t' + predicted_labels[index] )
# Out:
# अर्थशास्त्र	OTHER
# के	OTHER
# रचयिता	OTHER
# चाणक्य	B-Person
# के	OTHER
# बारे	OTHER
# में	OTHER
# कुछ	OTHER
# कहला	OTHER
# से	OTHER
# चुपे	OTHER
# रहल	OTHER
# ज्यादा	OTHER
# श्रद्धास्पद	OTHER
# होई	OTHER
# ।	OTHER

# %%
bh_X_te[2]
# Out:
# ['‘अर्थशास्त्र’',
#  'के',
#  'रचयिता',
#  'चाणक्य',
#  'के',
#  'बारे',
#  'में',
#  'कुछ',
#  'कहला',
#  'से',
#  'चुपे',
#  'रहल',
#  'ज्यादा',
#  'श्रद्धास्पद',
#  'होई',
#  '।']

# %%
mt_Y_tr = cat(mt_Y_tr)
df_mt_tr=pd.DataFrame(list(zip(mt_X_tr,mt_Y_tr)),columns=['tokens','ner_tags'])
dataset_mt_tr=Dataset.from_pandas(df_mt_tr)

# %%
raw_mt_te = open('/content/drive/MyDrive/bmmnerdataset/Maithili_ner[1].test').readlines()
mt_X_te,mt_Y_te=preprocess(raw_mt_te)
mt_Y_te = cat(mt_Y_te)
df_mt_te=pd.DataFrame(list(zip(mt_X_te,mt_Y_te)),columns=['tokens','ner_tags'])
dataset_mt_te=Dataset.from_pandas(df_mt_te)

# %%
mt_X_te[0]
# Out:
# ['आइ',
#  'विलासक',
#  'ओ',
#  'प्रमदावन',
#  ',',
#  'मात्र',
#  'प्रमाए',
#  'बटए',
#  'चित्रकूट',
#  'आ',
#  'पंचवटी',
#  'सब',
#  ',',
#  'उजड़ल',
#  'अवषेष',
#  'लगैए',
#  'घोर',
#  'प्रदूषण',
#  'गंगा',
#  'पाटल',
#  ',',
#  'धारक',
#  'नहि',
#  'आवेग',
#  'कनक',
#  'घूघरुक',
#  'इच्छा',
#  'करितहु',
#  ',',
#  'धरि',
#  'इजोर',
#  'के',
#  'देत',
#  '?']

# %%
raw_bh_tr = open('/content/drive/MyDrive/bmmnerdataset/Bhojpuri_ner.remove[1].train').readlines()
bh_X_tr,bh_Y_tr=preprocess(raw_bh_tr)
bh_Y_tr = cat(bh_Y_tr)
df_bh_tr=pd.DataFrame(list(zip(bh_X_tr,bh_Y_tr)),columns=['tokens','ner_tags'])
dataset_bh_tr=Dataset.from_pandas(df_bh_tr)
dataset_bh_ev=dataset_bh_tr.train_test_split(test_size=0.1)

# %%
raw_bh_te = open('/content/drive/MyDrive/bmmnerdataset/Bhojpuri_ner.remove[1].test').readlines()
bh_X_te,bh_Y_te=preprocess(raw_bh_te)
bh_Y_te = cat(bh_Y_te)
df_bh_te=pd.DataFrame(list(zip(bh_X_te,bh_Y_te)),columns=['tokens','ner_tags'])
dataset_bh_te=Dataset.from_pandas(df_bh_te)

# %%
raw_mg_tr = open('/content/drive/MyDrive/bmmnerdataset/Magahi_ner[1].train').readlines()
mg_X_tr,mg_Y_tr=preprocess(raw_mg_tr)

# %%
mg_Y_tr = cat(mg_Y_tr)
df_mg_tr=pd.DataFrame(list(zip(mg_X_tr,mg_Y_tr)),columns=['tokens','ner_tags'])
dataset_mg_tr=Dataset.from_pandas(df_mg_tr)

# %%
raw_mg_te = open('/content/drive/MyDrive/bmmnerdataset/Magahi_ner[1].test').readlines()
mg_X_te,mg_Y_te=preprocess(raw_mg_te)

# %%
mg_Y_te = cat(mg_Y_te)
df_mg_te=pd.DataFrame(list(zip(mg_X_te,mg_Y_te)),columns=['tokens','ner_tags'])
dataset_mg_te=Dataset.from_pandas(df_mg_te)

# %%
# Load model directly
from transformers import AutoModelForTokenClassification, AutoConfig, AutoTokenizer, TrainingArguments, Trainer, DataCollatorForTokenClassification, EarlyStoppingCallback, IntervalStrategy

#tokenizer = AutoTokenizer.from_pretrained("ai4bharat/IndicBERTv2-SS")
tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-base")
#model = AutoModelForTokenClassification.from_pretrained("ai4bharat/IndicBERTv2-SS",num_labels=n_labels)
model = AutoModelForTokenClassification.from_pretrained("xlm-roberta-base",num_labels=n_labels)
#model = AutoModelForTokenClassification.from_pretrained("ai4bharat/IndicNER",num_labels=n_labels,ignore_mismatched_sizes=True)
# Out:
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Load model directly
from transformers import AutoModelForTokenClassification, AutoConfig, AutoTokenizer, TrainingArguments, Trainer, DataCollatorForTokenClassification, EarlyStoppingCallback, IntervalStrategy
tokenizer = AutoTokenizer.from_pretrained("ai4bharat/IndicBERTv2-SS",keep_accents=True)
model = AutoModelForTokenClassification.from_pretrained("ai4bharat/IndicBERTv2-SS",num_labels=n_labels)
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/6.28M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/639 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at ai4bharat/IndicBERTv2-SS and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model=model.to("cuda")

# %%
text_column_name = "tokens"
label_column_name = "ner_tags"

# %%
# Tokenize all texts and align the labels with them.
padding = "max_length"
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples[text_column_name],
        padding=padding,
        truncation=True,
        max_length=512,
        # We use this argument because the texts in our dataset are lists of words (with a label for each word).
        is_split_into_words=True,
    )
    labels = []
    for i, label in enumerate(examples[label_column_name]):
        # print('=====')
        # print('{} {}'.format(i,label)) #ak
        word_ids = tokenized_inputs.word_ids(batch_index=i)

        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            # Special tokens have a word id that is None. We set the label to -100 so they are automatically
            # ignored in the loss function.
            if word_idx is None:
                label_ids.append(-100)
            # We set the label for the first token of each word.
            elif word_idx != previous_word_idx:
                label_ids.append(label[word_idx])
            # For the other tokens in a word, we set the label to either the current label or -100, depending on
            # the label_all_tokens flag.
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx

        labels.append(label_ids)
    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
sentence = '<mai> अर्थशास्त्र के रचयिता चाणक्य के बारे में कुछ कहला से चुपे रहल ज्यादा श्रद्धास्पद होई ।'

# %%
tokenizer.tokenize(sentence,)
# Out:
# ['[CLS]',
#  '<mai>',
#  'अर्थशास्त्र',
#  'के',
#  'रच',
#  '##यित',
#  '##ा',
#  'चाणक्य',
#  'के',
#  'बारे',
#  'में',
#  'कुछ',
#  'कहला',
#  'से',
#  'चुप',
#  '##े',
#  'रहल',
#  'ज्यादा',
#  'श्रद्धा',
#  '##स्पद',
#  'होई',
#  '।',
#  '[SEP]']

# %%
print(tokenizer.all_special_tokens)
# Out:
# ['[UNK]', '[SEP]', '[PAD]', '[CLS]', '[MASK]']

# %%
tokenizer1 = AutoTokenizer.from_pretrained("ai4bharat/IndicBERTv2-SS")
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/6.28M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
v=tokenizer.get_vocab()

# %%
print(tokenizer.all_special_tokens)
# Out:
# ['[UNK]', '[SEP]', '[PAD]', '[CLS]', '[MASK]']

# %%
tokenizer.tokenize(sentence)
# Out:
# ['अर्थशास्त्र',
#  'के',
#  'रचयिता',
#  'चाणक्य',
#  'के',
#  'बारे',
#  'में',
#  'कुछ',
#  'कहला',
#  'से',
#  'चुपे',
#  'रहल',
#  'ज्यादा',
#  'श्रद्धास्पद',
#  'होई',
#  '।']

# %%
data_collator = DataCollatorForTokenClassification(tokenizer)

# %%
# Metrics
metric = load_metric("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    # Remove ignored index (special tokens)
    true_predictions = [
        [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [label_list[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    # Unpack nested dictionaries
    final_results = {}
    for key, value in results.items():
        if isinstance(value, dict):
            for n, v in value.items():
                final_results[f"{key}_{n}"] = v
        else:
            final_results[key] = value
    return final_results
# Out:
# <ipython-input-20-435f98c90f62>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("seqeval")
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:752: FutureWarning: The repository for seqeval contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.16.0/metrics/seqeval/seqeval.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.47k [00:00<?, ?B/s]

# %%
train_dataset = dataset_mt_tr
train_dataset = train_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on train dataset",
)
# Out:
# Running tokenizer on train dataset (num_proc=4):   0%|          | 0/7848 [00:00<?, ? examples/s]

# %%
eval_dataset = concatenated_dataset["validation"]
eval_dataset = eval_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on eval dataset",
)
# Out:
# Running tokenizer on eval dataset (num_proc=4):   0%|          | 0/2366 [00:00<?, ? examples/s]

# %%
test_dataset = dataset_mt_te
test_dataset = test_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on test dataset",
)
# Out:
# Running tokenizer on test dataset (num_proc=4):   0%|          | 0/1965 [00:00<?, ? examples/s]

# %%
train_dataset = dataset_mg_tr
train_dataset = train_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on train dataset",
)
# Out:
# Running tokenizer on train dataset (num_proc=4):   0%|          | 0/4254 [00:00<?, ? examples/s]

# %%
test_dataset = dataset_mg_te
test_dataset = test_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on test dataset",
)
# Out:
# Running tokenizer on test dataset (num_proc=4):   0%|          | 0/1064 [00:00<?, ? examples/s]

# %%
# args=TrainingArguments(output_dir='output_dir',max_steps=5)
args=TrainingArguments(
    output_dir='output_dir1',
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=5
    )

# %%
# Initialize our Trainer
#early_stopping_callback = EarlyStoppingCallback(early_stopping_patience=4)
#args.metric_for_best_model = "f1"
#args.load_best_model_at_end = True
#args.evaluation_strategy = IntervalStrategy.STEPS
#args.eval_steps = args.save_steps
#args.greater_is_better = True

trainer = Trainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    #callbacks=[early_stopping_callback],
    args=args,
)

# %%
train_result = trainer.train('/content/output_dir1/checkpoint-2500')
# Out:
#     <div>
#
#       <progress value='4905' max='4905' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4905/4905 33:32, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3000</td>
#       <td>0.128200</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.107600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.096600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.079800</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='246' max='246' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [246/246 01:05]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        5.0
#   eval_Artifact_f1             =     0.5648
#   eval_Artifact_number         =        109
#   eval_Artifact_precision      =     0.5701
#   eval_Artifact_recall         =     0.5596
#   eval_Count_f1                =     0.6159
#   eval_Count_number            =        306
#   eval_Count_precision         =     0.5875
#   eval_Count_recall            =     0.6471
#   eval_Date_f1                 =       0.75
#   eval_Date_number             =         10
#   eval_Date_precision          =     0.6429
#   eval_Date_recall             =        0.9
#   eval_Day_f1                  =     0.4898
#   eval_Day_number              =         25
#   eval_Day_precision           =        0.5
#   eval_Day_recall              =       0.48
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          4
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =     0.7273
#   eval_Distance_number         =          4
#   eval_Distance_precision      =     0.5714
#   eval_Distance_recall         =        1.0
#   eval_Entertainment_f1        =     0.5391
#   eval_Entertainment_number    =         46
#   eval_Entertainment_precision =     0.4493
#   eval_Entertainment_recall    =     0.6739
#   eval_Facility_f1             =     0.6288
#   eval_Facility_number         =        113
#   eval_Facility_precision      =     0.6207
#   eval_Facility_recall         =     0.6372
#   eval_Location_f1             =     0.8208
#   eval_Location_number         =        795
#   eval_Location_precision      =     0.8177
#   eval_Location_recall         =     0.8239
#   eval_Locomotive_f1           =     0.6038
#   eval_Locomotive_number       =         27
#   eval_Locomotive_precision    =     0.6154
#   eval_Locomotive_recall       =     0.5926
#   eval_Material_f1             =     0.6587
#   eval_Material_number         =         83
#   eval_Material_precision      =     0.6548
#   eval_Material_recall         =     0.6627
#   eval_Money_f1                =     0.5294
#   eval_Money_number            =         14
#   eval_Money_precision         =       0.45
#   eval_Money_recall            =     0.6429
#   eval_Month_f1                =     0.9242
#   eval_Month_number            =         67
#   eval_Month_precision         =     0.9385
#   eval_Month_recall            =     0.9104
#   eval_Organism_f1             =     0.3059
#   eval_Organism_number         =         39
#   eval_Organism_precision      =     0.2826
#   eval_Organism_recall         =     0.3333
#   eval_Organization_f1         =     0.5946
#   eval_Organization_number     =        213
#   eval_Organization_precision  =     0.5714
#   eval_Organization_recall     =     0.6197
#   eval_Period_f1               =     0.6496
#   eval_Period_number           =         62
#   eval_Period_precision        =     0.6909
#   eval_Period_recall           =     0.6129
#   eval_Person_f1               =     0.7283
#   eval_Person_number           =        781
#   eval_Person_precision        =     0.7255
#   eval_Person_recall           =     0.7311
#   eval_Plant_f1                =     0.6207
#   eval_Plant_number            =         15
#   eval_Plant_precision         =     0.6429
#   eval_Plant_recall            =        0.6
#   eval_Quantity_f1             =     0.2708
#   eval_Quantity_number         =         64
#   eval_Quantity_precision      =     0.4062
#   eval_Quantity_recall         =     0.2031
#   eval_Special_Day_f1          =     0.5532
#   eval_Special_Day_number      =         24
#   eval_Special_Day_precision   =     0.5652
#   eval_Special_Day_recall      =     0.5417
#   eval_Time_f1                 =     0.3492
#   eval_Time_number             =         76
#   eval_Time_precision          =       0.44
#   eval_Time_recall             =     0.2895
#   eval_Year_f1                 =     0.8333
#   eval_Year_number             =         37
#   eval_Year_precision          =     0.8571
#   eval_Year_recall             =     0.8108
#   eval_loss                    =     0.2034
#   eval_overall_accuracy        =     0.9499
#   eval_overall_f1              =     0.6911
#   eval_overall_precision       =     0.6877
#   eval_overall_recall          =     0.6946
#   eval_runtime                 = 0:01:07.53
#   eval_samples_per_second      =     29.094
#   eval_steps_per_second        =      3.642

# %%
train_result = trainer.train()
# Out:
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3192' max='3192' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3192/3192 45:26, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.480100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.244800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.176000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.125700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.102400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.076700</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
train_result = trainer.train('/content/output_dir1/checkpoint-3000')
# Out:
#     <div>
#
#       <progress value='4256' max='4256' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4256/4256 18:06, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3500</td>
#       <td>0.075800</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.068600</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='133' max='133' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [133/133 00:33]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        8.0
#   eval_Artifact_f1             =     0.7235
#   eval_Artifact_number         =        152
#   eval_Artifact_precision      =     0.7518
#   eval_Artifact_recall         =     0.6974
#   eval_Count_f1                =     0.8151
#   eval_Count_number            =        127
#   eval_Count_precision         =     0.7826
#   eval_Count_recall            =     0.8504
#   eval_Date_f1                 =        0.0
#   eval_Date_number             =          3
#   eval_Date_precision          =        0.0
#   eval_Date_recall             =        0.0
#   eval_Day_f1                  =     0.8136
#   eval_Day_number              =         29
#   eval_Day_precision           =        0.8
#   eval_Day_recall              =     0.8276
#   eval_Disease_f1              =        0.5
#   eval_Disease_number          =          3
#   eval_Disease_precision       =        1.0
#   eval_Disease_recall          =     0.3333
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          1
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =        0.4
#   eval_Entertainment_number    =          4
#   eval_Entertainment_precision =        1.0
#   eval_Entertainment_recall    =       0.25
#   eval_Facility_f1             =     0.7917
#   eval_Facility_number         =         24
#   eval_Facility_precision      =     0.7917
#   eval_Facility_recall         =     0.7917
#   eval_Location_f1             =     0.7546
#   eval_Location_number         =        162
#   eval_Location_precision      =       0.75
#   eval_Location_recall         =     0.7593
#   eval_Locomotive_f1           =       0.75
#   eval_Locomotive_number       =         13
#   eval_Locomotive_precision    =     0.8182
#   eval_Locomotive_recall       =     0.6923
#   eval_Material_f1             =        0.8
#   eval_Material_number         =         74
#   eval_Material_precision      =     0.7442
#   eval_Material_recall         =     0.8649
#   eval_Money_f1                =     0.9333
#   eval_Money_number            =         30
#   eval_Money_precision         =     0.9333
#   eval_Money_recall            =     0.9333
#   eval_Month_f1                =     0.9143
#   eval_Month_number            =         17
#   eval_Month_precision         =     0.8889
#   eval_Month_recall            =     0.9412
#   eval_Organism_f1             =     0.7749
#   eval_Organism_number         =        136
#   eval_Organism_precision      =     0.7778
#   eval_Organism_recall         =     0.7721
#   eval_Organization_f1         =        0.5
#   eval_Organization_number     =          3
#   eval_Organization_precision  =        1.0
#   eval_Organization_recall     =     0.3333
#   eval_Period_f1               =        0.0
#   eval_Period_number           =         11
#   eval_Period_precision        =        0.0
#   eval_Period_recall           =        0.0
#   eval_Person_f1               =     0.8533
#   eval_Person_number           =        533
#   eval_Person_precision        =     0.8201
#   eval_Person_recall           =     0.8893
#   eval_Plant_f1                =     0.6667
#   eval_Plant_number            =         12
#   eval_Plant_precision         =     0.7778
#   eval_Plant_recall            =     0.5833
#   eval_Quantity_f1             =     0.4444
#   eval_Quantity_number         =         11
#   eval_Quantity_precision      =     0.5714
#   eval_Quantity_recall         =     0.3636
#   eval_Time_f1                 =      0.702
#   eval_Time_number             =         69
#   eval_Time_precision          =     0.6463
#   eval_Time_recall             =     0.7681
#   eval_Year_f1                 =     0.7368
#   eval_Year_number             =          9
#   eval_Year_precision          =        0.7
#   eval_Year_recall             =     0.7778
#   eval_loss                    =     0.2281
#   eval_overall_accuracy        =     0.9528
#   eval_overall_f1              =     0.7961
#   eval_overall_precision       =     0.7844
#   eval_overall_recall          =     0.8082
#   eval_runtime                 = 0:00:34.42
#   eval_samples_per_second      =     30.907
#   eval_steps_per_second        =      3.863

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='133' max='133' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [133/133 00:32]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        6.0
#   eval_Artifact_f1             =     0.7186
#   eval_Artifact_number         =        152
#   eval_Artifact_precision      =     0.7413
#   eval_Artifact_recall         =     0.6974
#   eval_Count_f1                =     0.8148
#   eval_Count_number            =        127
#   eval_Count_precision         =     0.7692
#   eval_Count_recall            =     0.8661
#   eval_Date_f1                 =        0.0
#   eval_Date_number             =          3
#   eval_Date_precision          =        0.0
#   eval_Date_recall             =        0.0
#   eval_Day_f1                  =     0.8387
#   eval_Day_number              =         29
#   eval_Day_precision           =     0.7879
#   eval_Day_recall              =     0.8966
#   eval_Disease_f1              =        0.5
#   eval_Disease_number          =          3
#   eval_Disease_precision       =        1.0
#   eval_Disease_recall          =     0.3333
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          1
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =        0.4
#   eval_Entertainment_number    =          4
#   eval_Entertainment_precision =        1.0
#   eval_Entertainment_recall    =       0.25
#   eval_Facility_f1             =     0.8085
#   eval_Facility_number         =         24
#   eval_Facility_precision      =     0.8261
#   eval_Facility_recall         =     0.7917
#   eval_Location_f1             =     0.7484
#   eval_Location_number         =        162
#   eval_Location_precision      =     0.7628
#   eval_Location_recall         =     0.7346
#   eval_Locomotive_f1           =       0.75
#   eval_Locomotive_number       =         13
#   eval_Locomotive_precision    =     0.8182
#   eval_Locomotive_recall       =     0.6923
#   eval_Material_f1             =     0.7778
#   eval_Material_number         =         74
#   eval_Material_precision      =     0.7159
#   eval_Material_recall         =     0.8514
#   eval_Money_f1                =     0.9333
#   eval_Money_number            =         30
#   eval_Money_precision         =     0.9333
#   eval_Money_recall            =     0.9333
#   eval_Month_f1                =     0.8889
#   eval_Month_number            =         17
#   eval_Month_precision         =     0.8421
#   eval_Month_recall            =     0.9412
#   eval_Organism_f1             =     0.7636
#   eval_Organism_number         =        136
#   eval_Organism_precision      =     0.7554
#   eval_Organism_recall         =     0.7721
#   eval_Organization_f1         =        0.5
#   eval_Organization_number     =          3
#   eval_Organization_precision  =        1.0
#   eval_Organization_recall     =     0.3333
#   eval_Period_f1               =        0.0
#   eval_Period_number           =         11
#   eval_Period_precision        =        0.0
#   eval_Period_recall           =        0.0
#   eval_Person_f1               =     0.8425
#   eval_Person_number           =        533
#   eval_Person_precision        =     0.8097
#   eval_Person_recall           =      0.878
#   eval_Plant_f1                =     0.6667
#   eval_Plant_number            =         12
#   eval_Plant_precision         =        1.0
#   eval_Plant_recall            =        0.5
#   eval_Quantity_f1             =     0.4706
#   eval_Quantity_number         =         11
#   eval_Quantity_precision      =     0.6667
#   eval_Quantity_recall         =     0.3636
#   eval_Time_f1                 =      0.726
#   eval_Time_number             =         69
#   eval_Time_precision          =     0.6883
#   eval_Time_recall             =     0.7681
#   eval_Year_f1                 =        0.7
#   eval_Year_number             =          9
#   eval_Year_precision          =     0.6364
#   eval_Year_recall             =     0.7778
#   eval_loss                    =     0.2136
#   eval_overall_accuracy        =     0.9518
#   eval_overall_f1              =     0.7906
#   eval_overall_precision       =      0.779
#   eval_overall_recall          =     0.8025
#   eval_runtime                 = 0:00:33.20
#   eval_samples_per_second      =     32.042
#   eval_steps_per_second        =      4.005

# %%
train_result = trainer.train()
# Out:
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1596' max='1596' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1596/1596 22:32, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.432400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.209500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.149500</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
train_result = trainer.train('/content/output_dir1/checkpoint-2000')
# Out:
#     <div>
#
#       <progress value='3192' max='3192' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3192/3192 16:29, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2500</td>
#       <td>0.111600</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.089800</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='133' max='133' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [133/133 00:35]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        6.0
#   eval_Artifact_f1             =     0.7677
#   eval_Artifact_number         =        152
#   eval_Artifact_precision      =     0.7862
#   eval_Artifact_recall         =       0.75
#   eval_Count_f1                =     0.7424
#   eval_Count_number            =        127
#   eval_Count_precision         =     0.7153
#   eval_Count_recall            =     0.7717
#   eval_Date_f1                 =        0.0
#   eval_Date_number             =          3
#   eval_Date_precision          =        0.0
#   eval_Date_recall             =        0.0
#   eval_Day_f1                  =     0.6667
#   eval_Day_number              =         29
#   eval_Day_precision           =     0.6786
#   eval_Day_recall              =     0.6552
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          3
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          1
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =     0.6667
#   eval_Entertainment_number    =          4
#   eval_Entertainment_precision =        1.0
#   eval_Entertainment_recall    =        0.5
#   eval_Facility_f1             =     0.8333
#   eval_Facility_number         =         24
#   eval_Facility_precision      =     0.8333
#   eval_Facility_recall         =     0.8333
#   eval_Location_f1             =      0.766
#   eval_Location_number         =        162
#   eval_Location_precision      =     0.7545
#   eval_Location_recall         =     0.7778
#   eval_Locomotive_f1           =     0.6429
#   eval_Locomotive_number       =         13
#   eval_Locomotive_precision    =        0.6
#   eval_Locomotive_recall       =     0.6923
#   eval_Material_f1             =     0.7333
#   eval_Material_number         =         74
#   eval_Material_precision      =     0.7237
#   eval_Material_recall         =     0.7432
#   eval_Money_f1                =     0.8421
#   eval_Money_number            =         30
#   eval_Money_precision         =     0.8889
#   eval_Money_recall            =        0.8
#   eval_Month_f1                =     0.8824
#   eval_Month_number            =         17
#   eval_Month_precision         =     0.8824
#   eval_Month_recall            =     0.8824
#   eval_Organism_f1             =     0.7609
#   eval_Organism_number         =        136
#   eval_Organism_precision      =       0.75
#   eval_Organism_recall         =     0.7721
#   eval_Organization_f1         =        0.0
#   eval_Organization_number     =          3
#   eval_Organization_precision  =        0.0
#   eval_Organization_recall     =        0.0
#   eval_Period_f1               =        0.0
#   eval_Period_number           =         11
#   eval_Period_precision        =        0.0
#   eval_Period_recall           =        0.0
#   eval_Person_f1               =     0.8183
#   eval_Person_number           =        533
#   eval_Person_precision        =     0.7858
#   eval_Person_recall           =     0.8537
#   eval_Plant_f1                =       0.75
#   eval_Plant_number            =         12
#   eval_Plant_precision         =       0.75
#   eval_Plant_recall            =       0.75
#   eval_Quantity_f1             =     0.5556
#   eval_Quantity_number         =         11
#   eval_Quantity_precision      =     0.7143
#   eval_Quantity_recall         =     0.4545
#   eval_Time_f1                 =     0.6069
#   eval_Time_number             =         69
#   eval_Time_precision          =     0.5789
#   eval_Time_recall             =     0.6377
#   eval_Year_f1                 =     0.7059
#   eval_Year_number             =          9
#   eval_Year_precision          =       0.75
#   eval_Year_recall             =     0.6667
#   eval_loss                    =      0.213
#   eval_overall_accuracy        =     0.9463
#   eval_overall_f1              =     0.7673
#   eval_overall_precision       =     0.7575
#   eval_overall_recall          =     0.7772
#   eval_runtime                 = 0:00:37.14
#   eval_samples_per_second      =     28.645
#   eval_steps_per_second        =      3.581

# %%
tokenizer.save_pretrained('/content/drive/MyDrive/mg_xlm')
model.save_pretrained('/content/drive/MyDrive/mg_xlm')

# %%
train_result = trainer.train()
# Out:
#     <div>
#
#       <progress value='2943' max='2943' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2943/2943 37:58, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.349300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.269800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.204000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.195900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.147700</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='246' max='246' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [246/246 01:04]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        3.0
#   eval_Artifact_f1             =     0.3041
#   eval_Artifact_number         =        109
#   eval_Artifact_precision      =     0.3056
#   eval_Artifact_recall         =     0.3028
#   eval_Count_f1                =     0.5877
#   eval_Count_number            =        306
#   eval_Count_precision         =     0.5429
#   eval_Count_recall            =     0.6405
#   eval_Date_f1                 =        0.7
#   eval_Date_number             =         10
#   eval_Date_precision          =        0.7
#   eval_Date_recall             =        0.7
#   eval_Day_f1                  =        0.0
#   eval_Day_number              =         25
#   eval_Day_precision           =        0.0
#   eval_Day_recall              =        0.0
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          4
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          4
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =     0.4681
#   eval_Entertainment_number    =         46
#   eval_Entertainment_precision =     0.4583
#   eval_Entertainment_recall    =     0.4783
#   eval_Facility_f1             =     0.3368
#   eval_Facility_number         =        113
#   eval_Facility_precision      =     0.4156
#   eval_Facility_recall         =     0.2832
#   eval_Location_f1             =     0.7742
#   eval_Location_number         =        795
#   eval_Location_precision      =     0.7699
#   eval_Location_recall         =     0.7786
#   eval_Locomotive_f1           =     0.2449
#   eval_Locomotive_number       =         27
#   eval_Locomotive_precision    =     0.2727
#   eval_Locomotive_recall       =     0.2222
#   eval_Material_f1             =     0.4359
#   eval_Material_number         =         83
#   eval_Material_precision      =     0.4658
#   eval_Material_recall         =     0.4096
#   eval_Money_f1                =     0.2857
#   eval_Money_number            =         14
#   eval_Money_precision         =     0.2857
#   eval_Money_recall            =     0.2857
#   eval_Month_f1                =     0.8714
#   eval_Month_number            =         67
#   eval_Month_precision         =     0.8356
#   eval_Month_recall            =     0.9104
#   eval_Organism_f1             =        0.0
#   eval_Organism_number         =         39
#   eval_Organism_precision      =        0.0
#   eval_Organism_recall         =        0.0
#   eval_Organization_f1         =     0.5896
#   eval_Organization_number     =        213
#   eval_Organization_precision  =     0.5924
#   eval_Organization_recall     =     0.5869
#   eval_Period_f1               =     0.5781
#   eval_Period_number           =         62
#   eval_Period_precision        =     0.5606
#   eval_Period_recall           =     0.5968
#   eval_Person_f1               =     0.6726
#   eval_Person_number           =        781
#   eval_Person_precision        =     0.6731
#   eval_Person_recall           =     0.6722
#   eval_Plant_f1                =        0.0
#   eval_Plant_number            =         15
#   eval_Plant_precision         =        0.0
#   eval_Plant_recall            =        0.0
#   eval_Quantity_f1             =     0.1714
#   eval_Quantity_number         =         64
#   eval_Quantity_precision      =        1.0
#   eval_Quantity_recall         =     0.0938
#   eval_Special_Day_f1          =        0.4
#   eval_Special_Day_number      =         24
#   eval_Special_Day_precision   =     0.3846
#   eval_Special_Day_recall      =     0.4167
#   eval_Time_f1                 =     0.2075
#   eval_Time_number             =         76
#   eval_Time_precision          =     0.3667
#   eval_Time_recall             =     0.1447
#   eval_Year_f1                 =     0.8182
#   eval_Year_number             =         37
#   eval_Year_precision          =      0.931
#   eval_Year_recall             =     0.7297
#   eval_loss                    =       0.24
#   eval_overall_accuracy        =     0.9398
#   eval_overall_f1              =      0.621
#   eval_overall_precision       =      0.641
#   eval_overall_recall          =     0.6023
#   eval_runtime                 = 0:01:06.27
#   eval_samples_per_second      =     29.649
#   eval_steps_per_second        =      3.712

# %%
# !rm -rf /content/output_dir1

# %%
trainer.args
# Out:
# TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=False,
# do_predict=False,
# do_train=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=output_dir1/runs/Dec15_09-01-28_f5dd04a78d1b,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=adamw_torch,
# optim_args=None,
# output_dir=output_dir1,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=output_dir1,
# save_on_each_node=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# split_batches=False,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )

# %%
# args=TrainingArguments(output_dir='output_dir',max_steps=5)
args=TrainingArguments(
    output_dir='output_dir1',
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    )

# %%
# Initialize our Trainer
#early_stopping_callback = EarlyStoppingCallback(early_stopping_patience=4)
#args.metric_for_best_model = "f1"
#args.load_best_model_at_end = True
#args.evaluation_strategy = IntervalStrategy.STEPS
#args.eval_steps = args.save_steps
#args.greater_is_better = True

trainer = Trainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    #callbacks=[early_stopping_callback],
    args=args,
)

# %%
train_result=trainer.train()
# Out:
#     <div>
#
#       <progress value='2943' max='2943' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2943/2943 41:21, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.457200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.253600</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.177700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.160100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.115500</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='246' max='246' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [246/246 01:03]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        3.0
#   eval_Artifact_f1             =     0.5758
#   eval_Artifact_number         =        109
#   eval_Artifact_precision      =     0.6404
#   eval_Artifact_recall         =     0.5229
#   eval_Count_f1                =     0.6121
#   eval_Count_number            =        306
#   eval_Count_precision         =     0.5706
#   eval_Count_recall            =     0.6601
#   eval_Date_f1                 =        0.9
#   eval_Date_number             =         10
#   eval_Date_precision          =        0.9
#   eval_Date_recall             =        0.9
#   eval_Day_f1                  =     0.2703
#   eval_Day_number              =         25
#   eval_Day_precision           =     0.4167
#   eval_Day_recall              =        0.2
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          4
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          4
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =      0.521
#   eval_Entertainment_number    =         46
#   eval_Entertainment_precision =     0.4247
#   eval_Entertainment_recall    =     0.6739
#   eval_Facility_f1             =     0.5413
#   eval_Facility_number         =        113
#   eval_Facility_precision      =     0.5619
#   eval_Facility_recall         =     0.5221
#   eval_Location_f1             =     0.8137
#   eval_Location_number         =        795
#   eval_Location_precision      =     0.8037
#   eval_Location_recall         =     0.8239
#   eval_Locomotive_f1           =     0.6316
#   eval_Locomotive_number       =         27
#   eval_Locomotive_precision    =        0.6
#   eval_Locomotive_recall       =     0.6667
#   eval_Material_f1             =     0.6708
#   eval_Material_number         =         83
#   eval_Material_precision      =     0.6923
#   eval_Material_recall         =     0.6506
#   eval_Money_f1                =     0.3871
#   eval_Money_number            =         14
#   eval_Money_precision         =     0.3529
#   eval_Money_recall            =     0.4286
#   eval_Month_f1                =     0.9065
#   eval_Month_number            =         67
#   eval_Month_precision         =      0.875
#   eval_Month_recall            =     0.9403
#   eval_Organism_f1             =     0.1569
#   eval_Organism_number         =         39
#   eval_Organism_precision      =     0.3333
#   eval_Organism_recall         =     0.1026
#   eval_Organization_f1         =     0.6023
#   eval_Organization_number     =        213
#   eval_Organization_precision  =     0.5901
#   eval_Organization_recall     =      0.615
#   eval_Period_f1               =     0.5882
#   eval_Period_number           =         62
#   eval_Period_precision        =      0.614
#   eval_Period_recall           =     0.5645
#   eval_Person_f1               =     0.7306
#   eval_Person_number           =        781
#   eval_Person_precision        =     0.7302
#   eval_Person_recall           =     0.7311
#   eval_Plant_f1                =     0.6087
#   eval_Plant_number            =         15
#   eval_Plant_precision         =      0.875
#   eval_Plant_recall            =     0.4667
#   eval_Quantity_f1             =     0.2338
#   eval_Quantity_number         =         64
#   eval_Quantity_precision      =     0.6923
#   eval_Quantity_recall         =     0.1406
#   eval_Special_Day_f1          =       0.64
#   eval_Special_Day_number      =         24
#   eval_Special_Day_precision   =     0.6154
#   eval_Special_Day_recall      =     0.6667
#   eval_Time_f1                 =     0.2957
#   eval_Time_number             =         76
#   eval_Time_precision          =     0.4359
#   eval_Time_recall             =     0.2237
#   eval_Year_f1                 =     0.8406
#   eval_Year_number             =         37
#   eval_Year_precision          =     0.9062
#   eval_Year_recall             =     0.7838
#   eval_loss                    =      0.181
#   eval_overall_accuracy        =     0.9507
#   eval_overall_f1              =     0.6868
#   eval_overall_precision       =      0.695
#   eval_overall_recall          =     0.6788
#   eval_runtime                 = 0:01:05.39
#   eval_samples_per_second      =     30.046
#   eval_steps_per_second        =      3.761

# %%
tokenizer.save_pretrained('/content/drive/MyDrive/mt_indicbertv2ss')
model.save_pretrained('/content/drive/MyDrive/mt_indicbertv2ss')

# %%
# args=TrainingArguments(output_dir='output_dir',max_steps=5)
args=TrainingArguments(
    output_dir='output_dir1',
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=5
    )

# %%
# Initialize our Trainer
#early_stopping_callback = EarlyStoppingCallback(early_stopping_patience=4)
#args.metric_for_best_model = "f1"
#args.load_best_model_at_end = True
#args.evaluation_strategy = IntervalStrategy.STEPS
#args.eval_steps = args.save_steps
#args.greater_is_better = True

trainer = Trainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    #callbacks=[early_stopping_callback],
    args=args,
)

# %%
train_result = trainer.train('/content/output_dir1/checkpoint-3500')
# Out:
#     <div>
#
#       <progress value='4905' max='4905' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4905/4905 19:26, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4000</td>
#       <td>0.097100</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.085200</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='246' max='246' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [246/246 01:03]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        5.0
#   eval_Artifact_f1             =      0.601
#   eval_Artifact_number         =        109
#   eval_Artifact_precision      =     0.6489
#   eval_Artifact_recall         =     0.5596
#   eval_Count_f1                =     0.5858
#   eval_Count_number            =        306
#   eval_Count_precision         =     0.5653
#   eval_Count_recall            =     0.6078
#   eval_Date_f1                 =     0.7826
#   eval_Date_number             =         10
#   eval_Date_precision          =     0.6923
#   eval_Date_recall             =        0.9
#   eval_Day_f1                  =       0.35
#   eval_Day_number              =         25
#   eval_Day_precision           =     0.4667
#   eval_Day_recall              =       0.28
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          4
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =     0.3333
#   eval_Distance_number         =          4
#   eval_Distance_precision      =        0.5
#   eval_Distance_recall         =       0.25
#   eval_Entertainment_f1        =     0.5739
#   eval_Entertainment_number    =         46
#   eval_Entertainment_precision =     0.4783
#   eval_Entertainment_recall    =     0.7174
#   eval_Facility_f1             =      0.569
#   eval_Facility_number         =        113
#   eval_Facility_precision      =     0.5546
#   eval_Facility_recall         =     0.5841
#   eval_Location_f1             =     0.8177
#   eval_Location_number         =        795
#   eval_Location_precision      =     0.8091
#   eval_Location_recall         =     0.8264
#   eval_Locomotive_f1           =     0.6667
#   eval_Locomotive_number       =         27
#   eval_Locomotive_precision    =     0.6333
#   eval_Locomotive_recall       =     0.7037
#   eval_Material_f1             =      0.675
#   eval_Material_number         =         83
#   eval_Material_precision      =     0.7013
#   eval_Material_recall         =     0.6506
#   eval_Money_f1                =     0.5625
#   eval_Money_number            =         14
#   eval_Money_precision         =        0.5
#   eval_Money_recall            =     0.6429
#   eval_Month_f1                =     0.9065
#   eval_Month_number            =         67
#   eval_Month_precision         =      0.875
#   eval_Month_recall            =     0.9403
#   eval_Organism_f1             =     0.1639
#   eval_Organism_number         =         39
#   eval_Organism_precision      =     0.2273
#   eval_Organism_recall         =     0.1282
#   eval_Organization_f1         =     0.5956
#   eval_Organization_number     =        213
#   eval_Organization_precision  =     0.5654
#   eval_Organization_recall     =     0.6291
#   eval_Period_f1               =      0.608
#   eval_Period_number           =         62
#   eval_Period_precision        =     0.6032
#   eval_Period_recall           =     0.6129
#   eval_Person_f1               =     0.7195
#   eval_Person_number           =        781
#   eval_Person_precision        =     0.7132
#   eval_Person_recall           =      0.726
#   eval_Plant_f1                =      0.625
#   eval_Plant_number            =         15
#   eval_Plant_precision         =     0.5882
#   eval_Plant_recall            =     0.6667
#   eval_Quantity_f1             =     0.2444
#   eval_Quantity_number         =         64
#   eval_Quantity_precision      =     0.4231
#   eval_Quantity_recall         =     0.1719
#   eval_Special_Day_f1          =     0.6809
#   eval_Special_Day_number      =         24
#   eval_Special_Day_precision   =     0.6957
#   eval_Special_Day_recall      =     0.6667
#   eval_Time_f1                 =     0.3902
#   eval_Time_number             =         76
#   eval_Time_precision          =     0.5106
#   eval_Time_recall             =     0.3158
#   eval_Year_f1                 =     0.8451
#   eval_Year_number             =         37
#   eval_Year_precision          =     0.8824
#   eval_Year_recall             =     0.8108
#   eval_loss                    =     0.1935
#   eval_overall_accuracy        =     0.9497
#   eval_overall_f1              =     0.6863
#   eval_overall_precision       =     0.6863
#   eval_overall_recall          =     0.6863
#   eval_runtime                 = 0:01:06.63
#   eval_samples_per_second      =     29.488
#   eval_steps_per_second        =      3.692

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='246' max='246' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [246/246 01:04]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        4.0
#   eval_Artifact_f1             =        0.6
#   eval_Artifact_number         =        109
#   eval_Artifact_precision      =     0.6593
#   eval_Artifact_recall         =     0.5505
#   eval_Count_f1                =     0.5927
#   eval_Count_number            =        306
#   eval_Count_precision         =     0.5754
#   eval_Count_recall            =     0.6111
#   eval_Date_f1                 =     0.8182
#   eval_Date_number             =         10
#   eval_Date_precision          =       0.75
#   eval_Date_recall             =        0.9
#   eval_Day_f1                  =     0.4255
#   eval_Day_number              =         25
#   eval_Day_precision           =     0.4545
#   eval_Day_recall              =        0.4
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          4
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =     0.3333
#   eval_Distance_number         =          4
#   eval_Distance_precision      =        0.5
#   eval_Distance_recall         =       0.25
#   eval_Entertainment_f1        =     0.5946
#   eval_Entertainment_number    =         46
#   eval_Entertainment_precision =     0.5077
#   eval_Entertainment_recall    =     0.7174
#   eval_Facility_f1             =     0.5714
#   eval_Facility_number         =        113
#   eval_Facility_precision      =     0.5766
#   eval_Facility_recall         =     0.5664
#   eval_Location_f1             =     0.8189
#   eval_Location_number         =        795
#   eval_Location_precision      =     0.8103
#   eval_Location_recall         =     0.8277
#   eval_Locomotive_f1           =     0.6552
#   eval_Locomotive_number       =         27
#   eval_Locomotive_precision    =     0.6129
#   eval_Locomotive_recall       =     0.7037
#   eval_Material_f1             =     0.6832
#   eval_Material_number         =         83
#   eval_Material_precision      =     0.7051
#   eval_Material_recall         =     0.6627
#   eval_Money_f1                =     0.5625
#   eval_Money_number            =         14
#   eval_Money_precision         =        0.5
#   eval_Money_recall            =     0.6429
#   eval_Month_f1                =     0.9313
#   eval_Month_number            =         67
#   eval_Month_precision         =     0.9531
#   eval_Month_recall            =     0.9104
#   eval_Organism_f1             =     0.1724
#   eval_Organism_number         =         39
#   eval_Organism_precision      =     0.2632
#   eval_Organism_recall         =     0.1282
#   eval_Organization_f1         =     0.6119
#   eval_Organization_number     =        213
#   eval_Organization_precision  =     0.5956
#   eval_Organization_recall     =     0.6291
#   eval_Period_f1               =     0.6129
#   eval_Period_number           =         62
#   eval_Period_precision        =     0.6129
#   eval_Period_recall           =     0.6129
#   eval_Person_f1               =     0.7243
#   eval_Person_number           =        781
#   eval_Person_precision        =     0.7188
#   eval_Person_recall           =     0.7298
#   eval_Plant_f1                =     0.5926
#   eval_Plant_number            =         15
#   eval_Plant_precision         =     0.6667
#   eval_Plant_recall            =     0.5333
#   eval_Quantity_f1             =     0.2326
#   eval_Quantity_number         =         64
#   eval_Quantity_precision      =     0.4545
#   eval_Quantity_recall         =     0.1562
#   eval_Special_Day_f1          =     0.6531
#   eval_Special_Day_number      =         24
#   eval_Special_Day_precision   =       0.64
#   eval_Special_Day_recall      =     0.6667
#   eval_Time_f1                 =     0.3577
#   eval_Time_number             =         76
#   eval_Time_precision          =     0.4681
#   eval_Time_recall             =     0.2895
#   eval_Year_f1                 =     0.8493
#   eval_Year_number             =         37
#   eval_Year_precision          =     0.8611
#   eval_Year_recall             =     0.8378
#   eval_loss                    =     0.1875
#   eval_overall_accuracy        =     0.9506
#   eval_overall_f1              =     0.6913
#   eval_overall_precision       =     0.6964
#   eval_overall_recall          =     0.6863
#   eval_runtime                 = 0:01:06.90
#   eval_samples_per_second      =     29.371
#   eval_steps_per_second        =      3.677

# %%
tokenizer.save_pretrained('/content/drive/MyDrive/mt_indicbertv2ss1')
model.save_pretrained('/content/drive/MyDrive/mt_indicbertv2ss1')

# %%
train_result = trainer.train('/content/output_dir/checkpoint-7000')
# Out:
#     <div>
#
#       <progress value='7500' max='7980' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7500/7980 07:43 < 07:26, 1.07 it/s, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Artifact Precision</th>
#       <th>Artifact Recall</th>
#       <th>Artifact F1</th>
#       <th>Artifact Number</th>
#       <th>Count Precision</th>
#       <th>Count Recall</th>
#       <th>Count F1</th>
#       <th>Count Number</th>
#       <th>Date Precision</th>
#       <th>Date Recall</th>
#       <th>Date F1</th>
#       <th>Date Number</th>
#       <th>Day Precision</th>
#       <th>Day Recall</th>
#       <th>Day F1</th>
#       <th>Day Number</th>
#       <th>Disease Precision</th>
#       <th>Disease Recall</th>
#       <th>Disease F1</th>
#       <th>Disease Number</th>
#       <th>Distance Precision</th>
#       <th>Distance Recall</th>
#       <th>Distance F1</th>
#       <th>Distance Number</th>
#       <th>Entertainment Precision</th>
#       <th>Entertainment Recall</th>
#       <th>Entertainment F1</th>
#       <th>Entertainment Number</th>
#       <th>Facility Precision</th>
#       <th>Facility Recall</th>
#       <th>Facility F1</th>
#       <th>Facility Number</th>
#       <th>Location Precision</th>
#       <th>Location Recall</th>
#       <th>Location F1</th>
#       <th>Location Number</th>
#       <th>Locomotive Precision</th>
#       <th>Locomotive Recall</th>
#       <th>Locomotive F1</th>
#       <th>Locomotive Number</th>
#       <th>Material Precision</th>
#       <th>Material Recall</th>
#       <th>Material F1</th>
#       <th>Material Number</th>
#       <th>Money Precision</th>
#       <th>Money Recall</th>
#       <th>Money F1</th>
#       <th>Money Number</th>
#       <th>Month Precision</th>
#       <th>Month Recall</th>
#       <th>Month F1</th>
#       <th>Month Number</th>
#       <th>Organism Precision</th>
#       <th>Organism Recall</th>
#       <th>Organism F1</th>
#       <th>Organism Number</th>
#       <th>Organization Precision</th>
#       <th>Organization Recall</th>
#       <th>Organization F1</th>
#       <th>Organization Number</th>
#       <th>Period Precision</th>
#       <th>Period Recall</th>
#       <th>Period F1</th>
#       <th>Period Number</th>
#       <th>Person Precision</th>
#       <th>Person Recall</th>
#       <th>Person F1</th>
#       <th>Person Number</th>
#       <th>Plant Precision</th>
#       <th>Plant Recall</th>
#       <th>Plant F1</th>
#       <th>Plant Number</th>
#       <th>Quantity Precision</th>
#       <th>Quantity Recall</th>
#       <th>Quantity F1</th>
#       <th>Quantity Number</th>
#       <th>Special Day Precision</th>
#       <th>Special Day Recall</th>
#       <th>Special Day F1</th>
#       <th>Special Day Number</th>
#       <th>Time Precision</th>
#       <th>Time Recall</th>
#       <th>Time F1</th>
#       <th>Time Number</th>
#       <th>Year Precision</th>
#       <th>Year Recall</th>
#       <th>Year F1</th>
#       <th>Year Number</th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>7500</td>
#       <td>0.108900</td>
#       <td>0.197660</td>
#       <td>0.385965</td>
#       <td>0.280255</td>
#       <td>0.324723</td>
#       <td>157</td>
#       <td>0.591837</td>
#       <td>0.591837</td>
#       <td>0.591837</td>
#       <td>196</td>
#       <td>0.583333</td>
#       <td>0.700000</td>
#       <td>0.636364</td>
#       <td>10</td>
#       <td>0.500000</td>
#       <td>0.176471</td>
#       <td>0.260870</td>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2</td>
#       <td>0.428571</td>
#       <td>0.217391</td>
#       <td>0.288462</td>
#       <td>69</td>
#       <td>0.523810</td>
#       <td>0.500000</td>
#       <td>0.511628</td>
#       <td>44</td>
#       <td>0.762178</td>
#       <td>0.713137</td>
#       <td>0.736842</td>
#       <td>373</td>
#       <td>0.454545</td>
#       <td>0.250000</td>
#       <td>0.322581</td>
#       <td>20</td>
#       <td>0.466667</td>
#       <td>0.350000</td>
#       <td>0.400000</td>
#       <td>60</td>
#       <td>0.333333</td>
#       <td>0.400000</td>
#       <td>0.363636</td>
#       <td>20</td>
#       <td>0.800000</td>
#       <td>0.857143</td>
#       <td>0.827586</td>
#       <td>28</td>
#       <td>0.577778</td>
#       <td>0.265306</td>
#       <td>0.363636</td>
#       <td>98</td>
#       <td>0.694118</td>
#       <td>0.614583</td>
#       <td>0.651934</td>
#       <td>96</td>
#       <td>0.406250</td>
#       <td>0.393939</td>
#       <td>0.400000</td>
#       <td>33</td>
#       <td>0.780973</td>
#       <td>0.747881</td>
#       <td>0.764069</td>
#       <td>944</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>9</td>
#       <td>0.130435</td>
#       <td>0.107143</td>
#       <td>0.117647</td>
#       <td>28</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>7</td>
#       <td>0.608696</td>
#       <td>0.474576</td>
#       <td>0.533333</td>
#       <td>59</td>
#       <td>0.857143</td>
#       <td>0.500000</td>
#       <td>0.631579</td>
#       <td>24</td>
#       <td>0.682516</td>
#       <td>0.599130</td>
#       <td>0.638111</td>
#       <td>0.952775</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
preds_bh,labels_bh,metrics_bh=trainer.predict(test_dataset_bh,metric_key_prefix="predict_bh")
# Out:
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
metrics_bh
# Out:
# {'predict_bh_loss': 0.12265395373106003,
#  'predict_bh_Artifact_precision': 0.2787878787878788,
#  'predict_bh_Artifact_recall': 0.27058823529411763,
#  'predict_bh_Artifact_f1': 0.27462686567164185,
#  'predict_bh_Artifact_number': 170,
#  'predict_bh_Count_precision': 0.37575757575757573,
#  'predict_bh_Count_recall': 0.389937106918239,
#  'predict_bh_Count_f1': 0.38271604938271603,
#  'predict_bh_Count_number': 159,
#  'predict_bh_Date_precision': 0.4375,
#  'predict_bh_Date_recall': 0.8235294117647058,
#  'predict_bh_Date_f1': 0.5714285714285714,
#  'predict_bh_Date_number': 17,
#  'predict_bh_Day_precision': 0.25,
#  'predict_bh_Day_recall': 0.1111111111111111,
#  'predict_bh_Day_f1': 0.15384615384615383,
#  'predict_bh_Day_number': 9,
#  'predict_bh_Disease_precision': 0.0,
#  'predict_bh_Disease_recall': 0.0,
#  'predict_bh_Disease_f1': 0.0,
#  'predict_bh_Disease_number': 9,
#  'predict_bh_Distance_precision': 0.0,
#  'predict_bh_Distance_recall': 0.0,
#  'predict_bh_Distance_f1': 0.0,
#  'predict_bh_Distance_number': 3,
#  'predict_bh_Entertainment_precision': 0.23333333333333334,
#  'predict_bh_Entertainment_recall': 0.0945945945945946,
#  'predict_bh_Entertainment_f1': 0.13461538461538464,
#  'predict_bh_Entertainment_number': 74,
#  'predict_bh_Facility_precision': 0.11538461538461539,
#  'predict_bh_Facility_recall': 0.09375,
#  'predict_bh_Facility_f1': 0.10344827586206896,
#  'predict_bh_Facility_number': 32,
#  'predict_bh_Location_precision': 0.7559808612440191,
#  'predict_bh_Location_recall': 0.61003861003861,
#  'predict_bh_Location_f1': 0.6752136752136753,
#  'predict_bh_Location_number': 259,
#  'predict_bh_Locomotive_precision': 0.30434782608695654,
#  'predict_bh_Locomotive_recall': 0.4,
#  'predict_bh_Locomotive_f1': 0.34567901234567905,
#  'predict_bh_Locomotive_number': 35,
#  'predict_bh_Material_precision': 0.1568627450980392,
#  'predict_bh_Material_recall': 0.0898876404494382,
#  'predict_bh_Material_f1': 0.11428571428571428,
#  'predict_bh_Material_number': 89,
#  'predict_bh_Money_precision': 0.13846153846153847,
#  'predict_bh_Money_recall': 0.2571428571428571,
#  'predict_bh_Money_f1': 0.18,
#  'predict_bh_Money_number': 35,
#  'predict_bh_Month_precision': 0.34782608695652173,
#  'predict_bh_Month_recall': 0.4,
#  'predict_bh_Month_f1': 0.37209302325581395,
#  'predict_bh_Month_number': 20,
#  'predict_bh_Organism_precision': 0.24528301886792453,
#  'predict_bh_Organism_recall': 0.2867647058823529,
#  'predict_bh_Organism_f1': 0.2644067796610169,
#  'predict_bh_Organism_number': 136,
#  'predict_bh_Organization_precision': 0.2,
#  'predict_bh_Organization_recall': 0.3125,
#  'predict_bh_Organization_f1': 0.24390243902439027,
#  'predict_bh_Organization_number': 16,
#  'predict_bh_Period_precision': 0.20967741935483872,
#  'predict_bh_Period_recall': 0.22033898305084745,
#  'predict_bh_Period_f1': 0.21487603305785125,
#  'predict_bh_Period_number': 59,
#  'predict_bh_Person_precision': 0.7979661016949152,
#  'predict_bh_Person_recall': 0.7672750977835724,
#  'predict_bh_Person_f1': 0.7823197075440347,
#  'predict_bh_Person_number': 1534,
#  'predict_bh_Plant_precision': 0.0,
#  'predict_bh_Plant_recall': 0.0,
#  'predict_bh_Plant_f1': 0.0,
#  'predict_bh_Plant_number': 44,
#  'predict_bh_Quantity_precision': 0.25,
#  'predict_bh_Quantity_recall': 0.01818181818181818,
#  'predict_bh_Quantity_f1': 0.03389830508474576,
#  'predict_bh_Quantity_number': 55,
#  'predict_bh_Special_Day_precision': 0.0,
#  'predict_bh_Special_Day_recall': 0.0,
#  'predict_bh_Special_Day_f1': 0.0,
#  'predict_bh_Special_Day_number': 1,
#  'predict_bh_Time_precision': 0.3225806451612903,
#  'predict_bh_Time_recall': 0.23809523809523808,
#  'predict_bh_Time_f1': 0.273972602739726,
#  'predict_bh_Time_number': 42,
#  'predict_bh_Year_precision': 0.4666666666666667,
#  'predict_bh_Year_recall': 0.6363636363636364,
#  'predict_bh_Year_f1': 0.5384615384615385,
#  'predict_bh_Year_number': 11,
#  'predict_bh_overall_precision': 0.6110467361915798,
#  'predict_bh_overall_recall': 0.563189747241011,
#  'predict_bh_overall_f1': 0.5861430159318265,
#  'predict_bh_overall_accuracy': 0.9674602242705337,
#  'predict_bh_runtime': 163.794,
#  'predict_bh_samples_per_second': 30.203,
#  'predict_bh_steps_per_second': 3.779}

# %%
train_dataset_mt = dataset_mt_ev['train']
train_dataset_mt = train_dataset_mt.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on train dataset",
)
# Out:
# Running tokenizer on train dataset (num_proc=4):   0%|          | 0/7063 [00:00<?, ? examples/s]

# %%
eval_dataset_mt = dataset_mt_ev['test']
eval_dataset_mt = eval_dataset_mt.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on validation dataset",
)
# Out:
# Running tokenizer on validation dataset (num_proc=4):   0%|          | 0/785 [00:00<?, ? examples/s]

# %%
test_dataset_mt = dataset_mt_te
test_dataset_mt = test_dataset_mt.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on test dataset",
)
# Out:
# Running tokenizer on test dataset (num_proc=4):   0%|          | 0/1965 [00:00<?, ? examples/s]

# %%
# args=TrainingArguments(output_dir='output_dir',max_steps=5)
args=TrainingArguments(
    output_dir='output_dir',
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    metric_for_best_model ='eval_loss',
    load_best_model_at_end=True,
    evaluation_strategy = IntervalStrategy.STEPS, # "steps"
    eval_steps = 500,
    save_total_limit = 5)

# %%
# Initialize our Trainer
early_stopping_callback = EarlyStoppingCallback(early_stopping_patience=4)
#args.metric_for_best_model = "f1"
#args.load_best_model_at_end = True
#args.evaluation_strategy = IntervalStrategy.STEPS
#args.eval_steps = args.save_steps
#args.greater_is_better = True

trainer = Trainer(
    model=model,
    train_dataset=train_dataset_mt,
    eval_dataset=eval_dataset_mt,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    callbacks=[early_stopping_callback],
    args=args,
)

# %%
train_result = trainer.train()
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='2649' max='2649' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2649/2649 36:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Artifact Precision</th>
#       <th>Artifact Recall</th>
#       <th>Artifact F1</th>
#       <th>Artifact Number</th>
#       <th>Count Precision</th>
#       <th>Count Recall</th>
#       <th>Count F1</th>
#       <th>Count Number</th>
#       <th>Date Precision</th>
#       <th>Date Recall</th>
#       <th>Date F1</th>
#       <th>Date Number</th>
#       <th>Day Precision</th>
#       <th>Day Recall</th>
#       <th>Day F1</th>
#       <th>Day Number</th>
#       <th>Disease Precision</th>
#       <th>Disease Recall</th>
#       <th>Disease F1</th>
#       <th>Disease Number</th>
#       <th>Distance Precision</th>
#       <th>Distance Recall</th>
#       <th>Distance F1</th>
#       <th>Distance Number</th>
#       <th>Entertainment Precision</th>
#       <th>Entertainment Recall</th>
#       <th>Entertainment F1</th>
#       <th>Entertainment Number</th>
#       <th>Facility Precision</th>
#       <th>Facility Recall</th>
#       <th>Facility F1</th>
#       <th>Facility Number</th>
#       <th>Location Precision</th>
#       <th>Location Recall</th>
#       <th>Location F1</th>
#       <th>Location Number</th>
#       <th>Locomotive Precision</th>
#       <th>Locomotive Recall</th>
#       <th>Locomotive F1</th>
#       <th>Locomotive Number</th>
#       <th>Material Precision</th>
#       <th>Material Recall</th>
#       <th>Material F1</th>
#       <th>Material Number</th>
#       <th>Money Precision</th>
#       <th>Money Recall</th>
#       <th>Money F1</th>
#       <th>Money Number</th>
#       <th>Month Precision</th>
#       <th>Month Recall</th>
#       <th>Month F1</th>
#       <th>Month Number</th>
#       <th>Organism Precision</th>
#       <th>Organism Recall</th>
#       <th>Organism F1</th>
#       <th>Organism Number</th>
#       <th>Organization Precision</th>
#       <th>Organization Recall</th>
#       <th>Organization F1</th>
#       <th>Organization Number</th>
#       <th>Period Precision</th>
#       <th>Period Recall</th>
#       <th>Period F1</th>
#       <th>Period Number</th>
#       <th>Person Precision</th>
#       <th>Person Recall</th>
#       <th>Person F1</th>
#       <th>Person Number</th>
#       <th>Quantity Precision</th>
#       <th>Quantity Recall</th>
#       <th>Quantity F1</th>
#       <th>Quantity Number</th>
#       <th>Special Day Precision</th>
#       <th>Special Day Recall</th>
#       <th>Special Day F1</th>
#       <th>Special Day Number</th>
#       <th>Time Precision</th>
#       <th>Time Recall</th>
#       <th>Time F1</th>
#       <th>Time Number</th>
#       <th>Year Precision</th>
#       <th>Year Recall</th>
#       <th>Year F1</th>
#       <th>Year Number</th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.644400</td>
#       <td>0.393606</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>48</td>
#       <td>0.518519</td>
#       <td>0.101449</td>
#       <td>0.169697</td>
#       <td>138</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>29</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>33</td>
#       <td>0.587859</td>
#       <td>0.619529</td>
#       <td>0.603279</td>
#       <td>297</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>44</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>12</td>
#       <td>0.400000</td>
#       <td>0.439560</td>
#       <td>0.418848</td>
#       <td>91</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>21</td>
#       <td>0.537217</td>
#       <td>0.535484</td>
#       <td>0.536349</td>
#       <td>310</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>13</td>
#       <td>0.539386</td>
#       <td>0.355634</td>
#       <td>0.428647</td>
#       <td>0.918925</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.340900</td>
#       <td>0.304611</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>48</td>
#       <td>0.516304</td>
#       <td>0.688406</td>
#       <td>0.590062</td>
#       <td>138</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>29</td>
#       <td>0.266667</td>
#       <td>0.121212</td>
#       <td>0.166667</td>
#       <td>33</td>
#       <td>0.669811</td>
#       <td>0.717172</td>
#       <td>0.692683</td>
#       <td>297</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>44</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>14</td>
#       <td>0.904762</td>
#       <td>0.760000</td>
#       <td>0.826087</td>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>12</td>
#       <td>0.471154</td>
#       <td>0.538462</td>
#       <td>0.502564</td>
#       <td>91</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>21</td>
#       <td>0.577049</td>
#       <td>0.567742</td>
#       <td>0.572358</td>
#       <td>310</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>19</td>
#       <td>1.000000</td>
#       <td>0.846154</td>
#       <td>0.916667</td>
#       <td>13</td>
#       <td>0.591241</td>
#       <td>0.499120</td>
#       <td>0.541289</td>
#       <td>0.931706</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.266600</td>
#       <td>0.282057</td>
#       <td>0.105263</td>
#       <td>0.041667</td>
#       <td>0.059701</td>
#       <td>48</td>
#       <td>0.657143</td>
#       <td>0.666667</td>
#       <td>0.661871</td>
#       <td>138</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.500000</td>
#       <td>0.068966</td>
#       <td>0.121212</td>
#       <td>29</td>
#       <td>0.500000</td>
#       <td>0.363636</td>
#       <td>0.421053</td>
#       <td>33</td>
#       <td>0.687097</td>
#       <td>0.717172</td>
#       <td>0.7
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
metrics = train_result.metrics

# %%
metrics
# Out:
# {'train_runtime': 2204.6447,
#  'train_samples_per_second': 9.611,
#  'train_steps_per_second': 1.202,
#  'total_flos': 5538769395747840.0,
#  'train_loss': 0.3238192205835892,
#  'epoch': 3.0}

# %%
metrics = trainer.evaluate()
trainer.log_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='99' max='99' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [99/99 00:25]
#     </div>
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** eval metrics *****
#   epoch                        =        3.0
#   eval_Artifact_f1             =     0.1978
#   eval_Artifact_number         =         48
#   eval_Artifact_precision      =     0.2093
#   eval_Artifact_recall         =     0.1875
#   eval_Count_f1                =     0.7046
#   eval_Count_number            =        138
#   eval_Count_precision         =     0.6923
#   eval_Count_recall            =     0.7174
#   eval_Date_f1                 =        0.5
#   eval_Date_number             =          2
#   eval_Date_precision          =        0.5
#   eval_Date_recall             =        0.5
#   eval_Day_f1                  =        0.0
#   eval_Day_number              =          5
#   eval_Day_precision           =        0.0
#   eval_Day_recall              =        0.0
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          1
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          1
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =     0.2769
#   eval_Entertainment_number    =         29
#   eval_Entertainment_precision =       0.25
#   eval_Entertainment_recall    =     0.3103
#   eval_Facility_f1             =     0.4194
#   eval_Facility_number         =         33
#   eval_Facility_precision      =     0.4483
#   eval_Facility_recall         =     0.3939
#   eval_Location_f1             =     0.7513
#   eval_Location_number         =        297
#   eval_Location_precision      =      0.777
#   eval_Location_recall         =     0.7273
#   eval_Locomotive_f1           =        0.0
#   eval_Locomotive_number       =         13
#   eval_Locomotive_precision    =        0.0
#   eval_Locomotive_recall       =        0.0
#   eval_Material_f1             =     0.3662
#   eval_Material_number         =         44
#   eval_Material_precision      =     0.4815
#   eval_Material_recall         =     0.2955
#   eval_Money_f1                =        0.0
#   eval_Money_number            =         14
#   eval_Money_precision         =        0.0
#   eval_Money_recall            =        0.0
#   eval_Month_f1                =     0.9583
#   eval_Month_number            =         25
#   eval_Month_precision         =        1.0
#   eval_Month_recall            =       0.92
#   eval_Organism_f1             =        0.0
#   eval_Organism_number         =         12
#   eval_Organism_precision      =        0.0
#   eval_Organism_recall         =        0.0
#   eval_Organization_f1         =     0.6154
#   eval_Organization_number     =         91
#   eval_Organization_precision  =     0.6154
#   eval_Organization_recall     =     0.6154
#   eval_Period_f1               =     0.2222
#   eval_Period_number           =         21
#   eval_Period_precision        =     0.2083
#   eval_Period_recall           =     0.2381
#   eval_Person_f1               =     0.6161
#   eval_Person_number           =        310
#   eval_Person_precision        =     0.6161
#   eval_Person_recall           =     0.6161
#   eval_Quantity_f1             =        0.0
#   eval_Quantity_number         =          7
#   eval_Quantity_precision      =        0.0
#   eval_Quantity_recall         =        0.0
#   eval_Special_Day_f1          =        0.3
#   eval_Special_Day_number      =         13
#   eval_Special_Day_precision   =     0.4286
#   eval_Special_Day_recall      =     0.2308
#   eval_Time_f1                 =        0.0
#   eval_Time_number             =         19
#   eval_Time_precision          =        0.0
#   eval_Time_recall             =        0.0
#   eval_Year_f1                 =     0.9231
#   eval_Year_number             =         13
#   eval_Year_precision          =     0.9231
#   eval_Year_recall             =     0.9231
#   eval_loss                    =     0.2747
#   eval_overall_accuracy        =       0.94
#   eval_overall_f1              =     0.6007
#   eval_overall_precision       =     0.6323
#   eval_overall_recall          =     0.5722
#   eval_runtime                 = 0:00:26.56
#   eval_samples_per_second      =     29.548
#   eval_steps_per_second        =      3.726

# %%
tokenizer.save_pretrained('/content/drive/MyDrive/bmm_model_mt')
model.save_pretrained('/content/drive/MyDrive/bmm_model_mt')

# %%
preds_mt,labels_mt,metrics_mt=trainer.predict(test_dataset_mt,metric_key_prefix="predict_mt")
# Out:
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
metrics_mt
# Out:
# {'predict_mt_loss': 0.2670222520828247,
#  'predict_mt_Artifact_precision': 0.1927710843373494,
#  'predict_mt_Artifact_recall': 0.14678899082568808,
#  'predict_mt_Artifact_f1': 0.16666666666666669,
#  'predict_mt_Artifact_number': 109,
#  'predict_mt_Count_precision': 0.5211267605633803,
#  'predict_mt_Count_recall': 0.6045751633986928,
#  'predict_mt_Count_f1': 0.5597579425113465,
#  'predict_mt_Count_number': 306,
#  'predict_mt_Date_precision': 0.8571428571428571,
#  'predict_mt_Date_recall': 0.6,
#  'predict_mt_Date_f1': 0.7058823529411764,
#  'predict_mt_Date_number': 10,
#  'predict_mt_Day_precision': 0.0,
#  'predict_mt_Day_recall': 0.0,
#  'predict_mt_Day_f1': 0.0,
#  'predict_mt_Day_number': 25,
#  'predict_mt_Disease_precision': 0.0,
#  'predict_mt_Disease_recall': 0.0,
#  'predict_mt_Disease_f1': 0.0,
#  'predict_mt_Disease_number': 4,
#  'predict_mt_Distance_precision': 0.0,
#  'predict_mt_Distance_recall': 0.0,
#  'predict_mt_Distance_f1': 0.0,
#  'predict_mt_Distance_number': 4,
#  'predict_mt_Entertainment_precision': 0.18947368421052632,
#  'predict_mt_Entertainment_recall': 0.391304347826087,
#  'predict_mt_Entertainment_f1': 0.2553191489361702,
#  'predict_mt_Entertainment_number': 46,
#  'predict_mt_Facility_precision': 0.44285714285714284,
#  'predict_mt_Facility_recall': 0.2743362831858407,
#  'predict_mt_Facility_f1': 0.33879781420765026,
#  'predict_mt_Facility_number': 113,
#  'predict_mt_Location_precision': 0.7457831325301205,
#  'predict_mt_Location_recall': 0.7786163522012579,
#  'predict_mt_Location_f1': 0.761846153846154,
#  'predict_mt_Location_number': 795,
#  'predict_mt_Locomotive_precision': 0.0,
#  'predict_mt_Locomotive_recall': 0.0,
#  'predict_mt_Locomotive_f1': 0.0,
#  'predict_mt_Locomotive_number': 27,
#  'predict_mt_Material_precision': 0.2982456140350877,
#  'predict_mt_Material_recall': 0.20481927710843373,
#  'predict_mt_Material_f1': 0.24285714285714285,
#  'predict_mt_Material_number': 83,
#  'predict_mt_Money_precision': 0.0,
#  'predict_mt_Money_recall': 0.0,
#  'predict_mt_Money_f1': 0.0,
#  'predict_mt_Money_number': 14,
#  'predict_mt_Month_precision': 0.7777777777777778,
#  'predict_mt_Month_recall': 0.9402985074626866,
#  'predict_mt_Month_f1': 0.8513513513513513,
#  'predict_mt_Month_number': 67,
#  'predict_mt_Organism_precision': 0.0,
#  'predict_mt_Organism_recall': 0.0,
#  'predict_mt_Organism_f1': 0.0,
#  'predict_mt_Organism_number': 39,
#  'predict_mt_Organization_precision': 0.6019900497512438,
#  'predict_mt_Organization_recall': 0.568075117370892,
#  'predict_mt_Organization_f1': 0.5845410628019324,
#  'predict_mt_Organization_number': 213,
#  'predict_mt_Period_precision': 0.3425925925925926,
#  'predict_mt_Period_recall': 0.5967741935483871,
#  'predict_mt_Period_f1': 0.43529411764705883,
#  'predict_mt_Period_number': 62,
#  'predict_mt_Person_precision': 0.6599749058971142,
#  'predict_mt_Person_recall': 0.6734955185659411,
#  'predict_mt_Person_f1': 0.6666666666666667,
#  'predict_mt_Person_number': 781,
#  'predict_mt_Plant_precision': 0.0,
#  'predict_mt_Plant_recall': 0.0,
#  'predict_mt_Plant_f1': 0.0,
#  'predict_mt_Plant_number': 15,
#  'predict_mt_Quantity_precision': 0.0,
#  'predict_mt_Quantity_recall': 0.0,
#  'predict_mt_Quantity_f1': 0.0,
#  'predict_mt_Quantity_number': 64,
#  'predict_mt_Special_Day_precision': 0.4,
#  'predict_mt_Special_Day_recall': 0.25,
#  'predict_mt_Special_Day_f1': 0.3076923076923077,
#  'predict_mt_Special_Day_number': 24,
#  'predict_mt_Time_precision': 0.0,
#  'predict_mt_Time_recall': 0.0,
#  'predict_mt_Time_f1': 0.0,
#  'predict_mt_Time_number': 76,
#  'predict_mt_Year_precision': 0.8888888888888888,
#  'predict_mt_Year_recall': 0.6486486486486487,
#  'predict_mt_Year_f1': 0.75,
#  'predict_mt_Year_number': 37,
#  'predict_mt_overall_precision': 0.6113553113553114,
#  'predict_mt_overall_recall': 0.5727522306108442,
#  'predict_mt_overall_f1': 0.5914245216158754,
#  'predict_mt_overall_accuracy': 0.9351331083614548,
#  'predict_mt_runtime': 67.8436,
#  'predict_mt_samples_per_second': 28.964,
#  'predict_mt_steps_per_second': 3.626}

# %%
train_dataset_mg = dataset_mg_ev['train']
train_dataset_mg = train_dataset_mg.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on train dataset",
)
# Out:
# Running tokenizer on train dataset (num_proc=4):   0%|          | 0/3828 [00:00<?, ? examples/s]

# %%
eval_dataset_mg = dataset_mg_ev['test']
eval_dataset_mg = eval_dataset_mg.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    load_from_cache_file=True,
    desc="Running tokenizer on validation dataset",
)
# Out:
# Running tokenizer on validation dataset (num_proc=4):   0%|          | 0/426 [00:00<?, ? examples/s]

# %%
test_dataset_mg = dataset_mg_te
test_dataset_mg = test_dataset_mg.map(
    tokenize_and_align_labels,
    batched=True,
    num_proc=4,
    desc="Running tokenizer on test dataset",
)
# Out:
# Running tokenizer on test dataset (num_proc=4):   0%|          | 0/1064 [00:00<?, ? examples/s]

# %%
# args=TrainingArguments(output_dir='output_dir',max_steps=5)
args1=TrainingArguments(
    output_dir='output_dir1',
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    metric_for_best_model ='eval_loss',
    load_best_model_at_end=True,
    evaluation_strategy = IntervalStrategy.STEPS, # "steps"
    eval_steps = 250,
    save_total_limit = 5)

# %%
# Initialize our Trainer
early_stopping_callback = EarlyStoppingCallback(early_stopping_patience=4)
#args.metric_for_best_model = "f1"
#args.load_best_model_at_end = True
#args.evaluation_strategy = IntervalStrategy.STEPS
#args.eval_steps = args.save_steps
#args.greater_is_better = True

trainer1 = Trainer(
    model=model,
    train_dataset=train_dataset_mg,
    eval_dataset=eval_dataset_mg,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    callbacks=[early_stopping_callback],
    args=args1,
)

# %%
train_result1 = trainer1.train()
# Out:
#     <div>
#
#       <progress value='1437' max='1437' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1437/1437 19:48, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Artifact Precision</th>
#       <th>Artifact Recall</th>
#       <th>Artifact F1</th>
#       <th>Artifact Number</th>
#       <th>Count Precision</th>
#       <th>Count Recall</th>
#       <th>Count F1</th>
#       <th>Count Number</th>
#       <th>Day Precision</th>
#       <th>Day Recall</th>
#       <th>Day F1</th>
#       <th>Day Number</th>
#       <th>Disease Precision</th>
#       <th>Disease Recall</th>
#       <th>Disease F1</th>
#       <th>Disease Number</th>
#       <th>Entertainment Precision</th>
#       <th>Entertainment Recall</th>
#       <th>Entertainment F1</th>
#       <th>Entertainment Number</th>
#       <th>Facility Precision</th>
#       <th>Facility Recall</th>
#       <th>Facility F1</th>
#       <th>Facility Number</th>
#       <th>Location Precision</th>
#       <th>Location Recall</th>
#       <th>Location F1</th>
#       <th>Location Number</th>
#       <th>Locomotive Precision</th>
#       <th>Locomotive Recall</th>
#       <th>Locomotive F1</th>
#       <th>Locomotive Number</th>
#       <th>Material Precision</th>
#       <th>Material Recall</th>
#       <th>Material F1</th>
#       <th>Material Number</th>
#       <th>Money Precision</th>
#       <th>Money Recall</th>
#       <th>Money F1</th>
#       <th>Money Number</th>
#       <th>Month Precision</th>
#       <th>Month Recall</th>
#       <th>Month F1</th>
#       <th>Month Number</th>
#       <th>Organism Precision</th>
#       <th>Organism Recall</th>
#       <th>Organism F1</th>
#       <th>Organism Number</th>
#       <th>Organization Precision</th>
#       <th>Organization Recall</th>
#       <th>Organization F1</th>
#       <th>Organization Number</th>
#       <th>Period Precision</th>
#       <th>Period Recall</th>
#       <th>Period F1</th>
#       <th>Period Number</th>
#       <th>Person Precision</th>
#       <th>Person Recall</th>
#       <th>Person F1</th>
#       <th>Person Number</th>
#       <th>Plant Precision</th>
#       <th>Plant Recall</th>
#       <th>Plant F1</th>
#       <th>Plant Number</th>
#       <th>Quantity Precision</th>
#       <th>Quantity Recall</th>
#       <th>Quantity F1</th>
#       <th>Quantity Number</th>
#       <th>Time Precision</th>
#       <th>Time Recall</th>
#       <th>Time F1</th>
#       <th>Time Number</th>
#       <th>Year Precision</th>
#       <th>Year Recall</th>
#       <th>Year F1</th>
#       <th>Year Number</th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>250</td>
#       <td>No log</td>
#       <td>0.308371</td>
#       <td>1.000000</td>
#       <td>0.160000</td>
#       <td>0.275862</td>
#       <td>50</td>
#       <td>0.645833</td>
#       <td>0.673913</td>
#       <td>0.659574</td>
#       <td>46</td>
#       <td>0.545455</td>
#       <td>0.857143</td>
#       <td>0.666667</td>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>7</td>
#       <td>0.540000</td>
#       <td>0.600000</td>
#       <td>0.568421</td>
#       <td>45</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4</td>
#       <td>1.000000</td>
#       <td>0.083333</td>
#       <td>0.153846</td>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>8</td>
#       <td>0.500000</td>
#       <td>0.444444</td>
#       <td>0.470588</td>
#       <td>9</td>
#       <td>0.461538</td>
#       <td>0.146341</td>
#       <td>0.222222</td>
#       <td>41</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>3</td>
#       <td>0.752475</td>
#       <td>0.700461</td>
#       <td>0.725537</td>
#       <td>217</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4</td>
#       <td>0.750000</td>
#       <td>0.111111</td>
#       <td>0.193548</td>
#       <td>27</td>
#       <td>0.400000</td>
#       <td>0.666667</td>
#       <td>0.500000</td>
#       <td>3</td>
#       <td>0.678284</td>
#       <td>0.492218</td>
#       <td>0.570462</td>
#       <td>0.918171</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.349500</td>
#       <td>0.260700</td>
#       <td>0.428571</td>
#       <td>0.360000</td>
#       <td>0.391304</td>
#       <td>50</td>
#       <td>0.642857</td>
#       <td>0.782609</td>
#       <td>0.705882</td>
#       <td>46</td>
#       <td>0.720000</td>
#       <td>0.857143</td>
#       <td>0.782609</td>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>1.000000</td>
#       <td>0.857143</td>
#       <td>0.923077</td>
#       <td>7</td>
#       <td>0.562500</td>
#       <td>0.800000</td>
#       <td>0.660550</td>
#       <td>45</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4</td>
#       <td>0.437500</td>
#       <td>0.291667</td>
#       <td>0.350000</td>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>8</td>
#       <td>1.000000</td>
#       <td>0.444444</td>
#       <td>0.615385</td>
#       <td>9</td>
#       <td>0.531915</td>
#       <td>0.609756</td>
#       <td>0.568182</td>
#       <td>41</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>3</td>
#       <td>0.771429</td>
#       <td>0.746544</td>
#       <td>0.758782</td>
#       <td>217</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4</td>
#       <td>0.666667</td>
#       <td>0.814815</td>
#       <td>0.733333</td>
#       <td>27</td>
#       <td>0.400000</td>
#       <td>0.666667</td>
#       <td>0.500000</td>
#       <td>3</td>
#       <td>0.660118</td>
#       <td>0.653696</td>
#       <td>0.656891</td>
#       <td>0.929660</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.349500</td>
#       <td>0.249146</td>
#       <td>0.527778</td>
#       <td>0.380000</td>
#       <td>0.441860</td>
#       <td>50</td>
#       <td>0.685185</td>
#       <td>0.804348</td>
#       <td>0.740000</td>
#       <td>46</td>
#       <td>0.894737</td>
#       <td>0.809524</td>
#       <td>0.850000</td>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>1.000000</td>
#       <td>0.857143</td>
#       <td>0.923077</td>
#       <td>7</td>
#       <td>0.631579</td>
#       <td>0.800000</td>
#       <td>0.705882</td>
#       <td>45</td>
#       <td>1.000000</td>
#       <td>0.250000</td>
#       <td>0.400000</td>
#       <td>4</td>
#       <td>0.400000</td>
#       <td>0.333333</td>
#       <td>0.363636</td>
#       <td>24</td>
#       <td>0.750000</td>
#       <td>0.375000</td>
#       <td>0.500000</td>
#       <td>8</td>
#       <td>0.636364</td>
#       <td>0.777778</td>
#       <td>0.700000</td>
#       <td>9</td>
#       <td>0.545455</td>
#       <td>0.585366</td>
#       <td>0.564706</td>
#       <td>41</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>3</td>
#       <td>0.670455</td>
#       <td>0.815668</td>
#       <td>0.735967</td>
#       <td>217</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</t
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
metrics1 = trainer1.evaluate()
# Out:
#     <div>
#
#       <progress value='54' max='54' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [54/54 00:13]
#     </div>
# ***** eval metrics *****
#   epoch                        =        3.0
#   eval_Artifact_f1             =     0.1978
#   eval_Artifact_number         =         48
#   eval_Artifact_precision      =     0.2093
#   eval_Artifact_recall         =     0.1875
#   eval_Count_f1                =     0.7046
#   eval_Count_number            =        138
#   eval_Count_precision         =     0.6923
#   eval_Count_recall            =     0.7174
#   eval_Date_f1                 =        0.5
#   eval_Date_number             =          2
#   eval_Date_precision          =        0.5
#   eval_Date_recall             =        0.5
#   eval_Day_f1                  =        0.0
#   eval_Day_number              =          5
#   eval_Day_precision           =        0.0
#   eval_Day_recall              =        0.0
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          1
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Distance_f1             =        0.0
#   eval_Distance_number         =          1
#   eval_Distance_precision      =        0.0
#   eval_Distance_recall         =        0.0
#   eval_Entertainment_f1        =     0.2769
#   eval_Entertainment_number    =         29
#   eval_Entertainment_precision =       0.25
#   eval_Entertainment_recall    =     0.3103
#   eval_Facility_f1             =     0.4194
#   eval_Facility_number         =         33
#   eval_Facility_precision      =     0.4483
#   eval_Facility_recall         =     0.3939
#   eval_Location_f1             =     0.7513
#   eval_Location_number         =        297
#   eval_Location_precision      =      0.777
#   eval_Location_recall         =     0.7273
#   eval_Locomotive_f1           =        0.0
#   eval_Locomotive_number       =         13
#   eval_Locomotive_precision    =        0.0
#   eval_Locomotive_recall       =        0.0
#   eval_Material_f1             =     0.3662
#   eval_Material_number         =         44
#   eval_Material_precision      =     0.4815
#   eval_Material_recall         =     0.2955
#   eval_Money_f1                =        0.0
#   eval_Money_number            =         14
#   eval_Money_precision         =        0.0
#   eval_Money_recall            =        0.0
#   eval_Month_f1                =     0.9583
#   eval_Month_number            =         25
#   eval_Month_precision         =        1.0
#   eval_Month_recall            =       0.92
#   eval_Organism_f1             =        0.0
#   eval_Organism_number         =         12
#   eval_Organism_precision      =        0.0
#   eval_Organism_recall         =        0.0
#   eval_Organization_f1         =     0.6154
#   eval_Organization_number     =         91
#   eval_Organization_precision  =     0.6154
#   eval_Organization_recall     =     0.6154
#   eval_Period_f1               =     0.2222
#   eval_Period_number           =         21
#   eval_Period_precision        =     0.2083
#   eval_Period_recall           =     0.2381
#   eval_Person_f1               =     0.6161
#   eval_Person_number           =        310
#   eval_Person_precision        =     0.6161
#   eval_Person_recall           =     0.6161
#   eval_Quantity_f1             =        0.0
#   eval_Quantity_number         =          7
#   eval_Quantity_precision      =        0.0
#   eval_Quantity_recall         =        0.0
#   eval_Special_Day_f1          =        0.3
#   eval_Special_Day_number      =         13
#   eval_Special_Day_precision   =     0.4286
#   eval_Special_Day_recall      =     0.2308
#   eval_Time_f1                 =        0.0
#   eval_Time_number             =         19
#   eval_Time_precision          =        0.0
#   eval_Time_recall             =        0.0
#   eval_Year_f1                 =     0.9231
#   eval_Year_number             =         13
#   eval_Year_precision          =     0.9231
#   eval_Year_recall             =     0.9231
#   eval_loss                    =     0.2747
#   eval_overall_accuracy        =       0.94
#   eval_overall_f1              =     0.6007
#   eval_overall_precision       =     0.6323
#   eval_overall_recall          =     0.5722
#   eval_runtime                 = 0:00:26.56
#   eval_samples_per_second      =     29.548
#   eval_steps_per_second        =      3.726
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: OTHER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
trainer1.log_metrics("eval", metrics1)
# Out:
# ***** eval metrics *****
#   epoch                        =        3.0
#   eval_Artifact_f1             =     0.4138
#   eval_Artifact_number         =         50
#   eval_Artifact_precision      =     0.4865
#   eval_Artifact_recall         =       0.36
#   eval_Count_f1                =     0.7429
#   eval_Count_number            =         46
#   eval_Count_precision         =      0.661
#   eval_Count_recall            =     0.8478
#   eval_Day_f1                  =      0.766
#   eval_Day_number              =         21
#   eval_Day_precision           =     0.6923
#   eval_Day_recall              =     0.8571
#   eval_Disease_f1              =        0.0
#   eval_Disease_number          =          1
#   eval_Disease_precision       =        0.0
#   eval_Disease_recall          =        0.0
#   eval_Entertainment_f1        =        0.0
#   eval_Entertainment_number    =          1
#   eval_Entertainment_precision =        0.0
#   eval_Entertainment_recall    =        0.0
#   eval_Facility_f1             =     0.9231
#   eval_Facility_number         =          7
#   eval_Facility_precision      =        1.0
#   eval_Facility_recall         =     0.8571
#   eval_Location_f1             =      0.729
#   eval_Location_number         =         45
#   eval_Location_precision      =      0.629
#   eval_Location_recall         =     0.8667
#   eval_Locomotive_f1           =        0.4
#   eval_Locomotive_number       =          4
#   eval_Locomotive_precision    =        1.0
#   eval_Locomotive_recall       =       0.25
#   eval_Material_f1             =      0.383
#   eval_Material_number         =         24
#   eval_Material_precision      =     0.3913
#   eval_Material_recall         =      0.375
#   eval_Money_f1                =        0.5
#   eval_Money_number            =          8
#   eval_Money_precision         =        0.5
#   eval_Money_recall            =        0.5
#   eval_Month_f1                =      0.875
#   eval_Month_number            =          9
#   eval_Month_precision         =        1.0
#   eval_Month_recall            =     0.7778
#   eval_Organism_f1             =     0.6279
#   eval_Organism_number         =         41
#   eval_Organism_precision      =        0.6
#   eval_Organism_recall         =     0.6585
#   eval_Organization_f1         =        0.0
#   eval_Organization_number     =          2
#   eval_Organization_precision  =        0.0
#   eval_Organization_recall     =        0.0
#   eval_Period_f1               =        0.0
#   eval_Period_number           =          3
#   eval_Period_precision        =        0.0
#   eval_Period_recall           =        0.0
#   eval_Person_f1               =     0.7712
#   eval_Person_number           =        217
#   eval_Person_precision        =     0.7137
#   eval_Person_recall           =     0.8387
#   eval_Plant_f1                =        0.0
#   eval_Plant_number            =          1
#   eval_Plant_precision         =        0.0
#   eval_Plant_recall            =        0.0
#   eval_Quantity_f1             =        0.0
#   eval_Quantity_number         =          4
#   eval_Quantity_precision      =        0.0
#   eval_Quantity_recall         =        0.0
#   eval_Time_f1                 =        0.7
#   eval_Time_number             =         27
#   eval_Time_precision          =     0.6364
#   eval_Time_recall             =     0.7778
#   eval_Year_f1                 =        0.8
#   eval_Year_number             =          3
#   eval_Year_precision          =        1.0
#   eval_Year_recall             =     0.6667
#   eval_loss                    =     0.2542
#   eval_overall_accuracy        =     0.9341
#   eval_overall_f1              =      0.692
#   eval_overall_precision       =     0.6613
#   eval_overall_recall          =     0.7257
#   eval_runtime                 = 0:00:14.13
#   eval_samples_per_second      =     30.146
#   eval_steps_per_second        =      3.821

# %%
len(eval_dataset_mg)
# Out:
# 426

# %%
len(eval_dataset_mt)
# Out:
# 785

# %%
tokenizer.save_pretrained('/content/drive/MyDrive/bmm_model_mg')
model.save_pretrained('/content/drive/MyDrive/bmm_model_mg')

# %%
preds_mg,labels_mg,metrics_mg=trainer1.predict(test_dataset_mg,metric_key_prefix="predict_mg")

# %%
metrics_mg
# Out:
# {'predict_mg_loss': 0.2614980936050415,
#  'predict_mg_Artifact_precision': 0.5891472868217055,
#  'predict_mg_Artifact_recall': 0.5,
#  'predict_mg_Artifact_f1': 0.5409252669039145,
#  'predict_mg_Artifact_number': 152,
#  'predict_mg_Count_precision': 0.668918918918919,
#  'predict_mg_Count_recall': 0.7795275590551181,
#  'predict_mg_Count_f1': 0.7200000000000001,
#  'predict_mg_Count_number': 127,
#  'predict_mg_Date_precision': 0.0,
#  'predict_mg_Date_recall': 0.0,
#  'predict_mg_Date_f1': 0.0,
#  'predict_mg_Date_number': 3,
#  'predict_mg_Day_precision': 0.5833333333333334,
#  'predict_mg_Day_recall': 0.7241379310344828,
#  'predict_mg_Day_f1': 0.6461538461538462,
#  'predict_mg_Day_number': 29,
#  'predict_mg_Disease_precision': 0.0,
#  'predict_mg_Disease_recall': 0.0,
#  'predict_mg_Disease_f1': 0.0,
#  'predict_mg_Disease_number': 3,
#  'predict_mg_Distance_precision': 0.0,
#  'predict_mg_Distance_recall': 0.0,
#  'predict_mg_Distance_f1': 0.0,
#  'predict_mg_Distance_number': 1,
#  'predict_mg_Entertainment_precision': 0.0,
#  'predict_mg_Entertainment_recall': 0.0,
#  'predict_mg_Entertainment_f1': 0.0,
#  'predict_mg_Entertainment_number': 4,
#  'predict_mg_Facility_precision': 0.6071428571428571,
#  'predict_mg_Facility_recall': 0.7083333333333334,
#  'predict_mg_Facility_f1': 0.6538461538461539,
#  'predict_mg_Facility_number': 24,
#  'predict_mg_Location_precision': 0.7045454545454546,
#  'predict_mg_Location_recall': 0.7654320987654321,
#  'predict_mg_Location_f1': 0.7337278106508877,
#  'predict_mg_Location_number': 162,
#  'predict_mg_Locomotive_precision': 0.3333333333333333,
#  'predict_mg_Locomotive_recall': 0.07692307692307693,
#  'predict_mg_Locomotive_f1': 0.125,
#  'predict_mg_Locomotive_number': 13,
#  'predict_mg_Material_precision': 0.5833333333333334,
#  'predict_mg_Material_recall': 0.5675675675675675,
#  'predict_mg_Material_f1': 0.5753424657534246,
#  'predict_mg_Material_number': 74,
#  'predict_mg_Money_precision': 0.7058823529411765,
#  'predict_mg_Money_recall': 0.8,
#  'predict_mg_Money_f1': 0.7500000000000001,
#  'predict_mg_Money_number': 30,
#  'predict_mg_Month_precision': 1.0,
#  'predict_mg_Month_recall': 0.8235294117647058,
#  'predict_mg_Month_f1': 0.9032258064516129,
#  'predict_mg_Month_number': 17,
#  'predict_mg_Organism_precision': 0.5857142857142857,
#  'predict_mg_Organism_recall': 0.6029411764705882,
#  'predict_mg_Organism_f1': 0.5942028985507247,
#  'predict_mg_Organism_number': 136,
#  'predict_mg_Organization_precision': 0.2,
#  'predict_mg_Organization_recall': 0.3333333333333333,
#  'predict_mg_Organization_f1': 0.25,
#  'predict_mg_Organization_number': 3,
#  'predict_mg_Period_precision': 0.0,
#  'predict_mg_Period_recall': 0.0,
#  'predict_mg_Period_f1': 0.0,
#  'predict_mg_Period_number': 11,
#  'predict_mg_Person_precision': 0.7816291161178509,
#  'predict_mg_Person_recall': 0.8461538461538461,
#  'predict_mg_Person_f1': 0.8126126126126125,
#  'predict_mg_Person_number': 533,
#  'predict_mg_Plant_precision': 0.0,
#  'predict_mg_Plant_recall': 0.0,
#  'predict_mg_Plant_f1': 0.0,
#  'predict_mg_Plant_number': 12,
#  'predict_mg_Quantity_precision': 0.0,
#  'predict_mg_Quantity_recall': 0.0,
#  'predict_mg_Quantity_f1': 0.0,
#  'predict_mg_Quantity_number': 11,
#  'predict_mg_Time_precision': 0.5365853658536586,
#  'predict_mg_Time_recall': 0.6376811594202898,
#  'predict_mg_Time_f1': 0.5827814569536424,
#  'predict_mg_Time_number': 69,
#  'predict_mg_Year_precision': 1.0,
#  'predict_mg_Year_recall': 0.5555555555555556,
#  'predict_mg_Year_f1': 0.7142857142857143,
#  'predict_mg_Year_number': 9,
#  'predict_mg_overall_precision': 0.6908212560386473,
#  'predict_mg_overall_recall': 0.7034434293745608,
#  'predict_mg_overall_f1': 0.697075208913649,
#  'predict_mg_overall_accuracy': 0.93381510531418,
#  'predict_mg_runtime': 36.1566,
#  'predict_mg_samples_per_second': 29.428,
#  'predict_mg_steps_per_second': 3.678}

# %%
tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/bmm_model_com",local_files_only=True)

model = AutoModelForTokenClassification.from_pretrained("/content/drive/MyDrive/bmm_model_com",local_files_only=True)

# %%
# args=TrainingArguments(output_dir='output_dir',max_steps=5)
args1=TrainingArguments(
    output_dir='output_dir2',
    per_device_eval_batch_size=8,
    do_train = False,
    do_predict = True,)

# %%
# Initialize our Trainer
#early_stopping_callback = EarlyStoppingCallback(early_stopping_patience=4)
#args.metric_for_best_model = "f1"
#args.load_best_model_at_end = True
#args.evaluation_strategy = IntervalStrategy.STEPS
#args.eval_steps = args.save_steps
#args.greater_is_better = True

trainer2 = Trainer(
    model=model,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    args=args1,
)

# %%
model=model.to('cuda')

# %%
preds_mt,labels_mt,metrics_mt=trainer2.predict(test_dataset_mt,metric_key_prefix="predict_mt")
